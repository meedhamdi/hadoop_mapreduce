# %% [markdown]
# # Anagrams
#
# In this exercise we reiterate over the previous Anagrams example from TP1.
# We run a local Spark program to solve the exercise.
#
# Let's start by importing the Spark Context:

# %%
from pyspark import SparkContext

# %% [markdown]
# Next, we create an instance of SparkContext:

# %%
sc = SparkContext()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %% [markdown]
# Now we want to get our data from HDFS.
# Let's check whether the file is already there:
#
# > Note that by starting the line with `!` we run a bash command instead of python code.

# %%
# !hadoop fs -ls common_words_en_subset.txt
# Out:
# -rw-r--r--   1 vagrant supergroup       9301 2022-12-27 04:53 common_words_en_subset.txt

# %% [markdown]
# If the file don't show up you can put it on HDFS:

# %%
# !hadoop fs -put /vagrant/tp/1/common_words_en_subset.txt

# %% [markdown]
# Next, we load the data into a Spark RDD (note that this command is lazily evaluated)

# %%
words = sc.textFile('common_words_en_subset.txt')
words
# Out:
# common_words_en_subset.txt MapPartitionsRDD[1] at textFile at NativeMethodAccessorImpl.java:0

# %% [markdown]
# Let's display the content of the `words` RDD:

# %%
words.collect()
# Out:
# ['acrimonious',
#  'aerodyne',
#  'acariasis',
#  'actually',
#  'abomasum',
#  'achene',
#  'abscess',
#  'adorn',
#  'acentric',
#  'absentee',
#  'afterheat',
#  'abbreviated',
#  'aft',
#  'adrift',
#  'adsorbate',
#  'acquirement',
#  'acheron',
#  'accelerator',
#  'abohm',
#  'aargau',
#  'afoot',
#  'aegean',
#  'acrimony',
#  'actuality',
#  'aeolipile',
#  'acrobatics',
#  'acceptation',
#  'affinal',
#  'aeneid',
#  'acquit',
#  'affectionate',
#  'afrikaans',
#  'abundant',
#  'abducent',
#  'acrodont',
#  'aforethought',
#  'adulterate',
#  'acolyte',
#  'adown',
#  'abbatial',
#  'addams',
#  'teatime',
#  'adverse',
#  'abele',
#  'aerostation',
#  'afro',
#  'accompaniment',
#  'afeard',
#  'afterthought',
#  'afterworld',
#  'ablate',
#  'achaea',
#  'abscond',
#  'accountable',
#  'acerbity',
#  'acrocarpous',
#  'aerostatics',
#  'aegisthus',
#  'adjust',
#  'acetyl',
#  'acquainted',
#  'account',
#  'africanize',
#  'abstracted',
#  'aerobic',
#  'absorber',
#  'aeromedical',
#  'admetus',
#  'acromion',
#  'acuminate',
#  'aa',
#  'afrikaner',
#  'addictive',
#  'accentuation',
#  'a',
#  'abecedarian',
#  'accrescent',
#  'accident',
#  'adjudge',
#  'affixation',
#  'adulteration',
#  'aerostatic',
#  'acrophobia',
#  'abacus',
#  'aegina',
#  'aciculate',
#  'abandoned',
#  'accrual',
#  'acrilan',
#  'deer',
#  'academicism',
#  'affiant',
#  'accelerant',
#  'aerophone',
#  'abhenry',
#  'abatement',
#  'acetamide',
#  'acumen',
#  'admeasurement',
#  'abridge',
#  'accroach',
#  'abreast',
#  'adhesive',
#  'afterpiece',
#  'adscititious',
#  'adp',
#  'afghanistan',
#  'adrianople',
#  'acatalectic',
#  'accrue',
#  'absently',
#  'achelous',
#  'abscind',
#  'activity',
#  'aerialist',
#  'adrenocorticotropic',
#  'accredit',
#  'advisement',
#  'addlepated',
#  'aegir',
#  'actiniform',
#  'afterdeck',
#  'achlamydeous',
#  'acedia',
#  'adagietto',
#  'abortionist',
#  'achievement',
#  'administer',
#  'accrete',
#  'accentuate',
#  'acropetal',
#  'addax',
#  'aerology',
#  'abaft',
#  'aconite',
#  'aerify',
#  'adder',
#  'adjure',
#  'actinopod',
#  'aculeate',
#  'adjoint',
#  'acidulant',
#  'afrikander',
#  'aesthetically',
#  'absolutism',
#  'abbevillian',
#  'aeolis',
#  'abuzz',
#  'aeronaut',
#  'admiration',
#  'aero',
#  'abamp',
#  'aeon',
#  'aeolic',
#  'adjournment',
#  'acetophenetidin',
#  'afterguard',
#  'adipose',
#  'acetify',
#  'afraid',
#  'admix',
#  'aberdeen',
#  'academician',
#  'affined',
#  'abeyance',
#  'aftermost',
#  'admonition',
#  'abstain',
#  'adverb',
#  'abwatt',
#  'administration',
#  'aesthetics',
#  'afloat',
#  'aerophagia',
#  'after',
#  'adulthood',
#  'abfarad',
#  'admiralty',
#  'advection',
#  'adapter',
#  'abash',
#  'absorptivity',
#  'affected',
#  'additive',
#  'abelmosk',
#  'adjoin',
#  'adolescence',
#  'abdias',
#  'accomplished',
#  'afterbody',
#  'aecium',
#  'addressograph',
#  'abseil',
#  'affettuoso',
#  'adventurism',
#  'accommodate',
#  'adage',
#  'addison',
#  'aforesaid',
#  'affianced',
#  'abundance',
#  'affront',
#  'adequate',
#  'acidulous',
#  'adscription',
#  'abutter',
#  'actinism',
#  'aeropause',
#  'aachen',
#  'actinal',
#  'aesthete',
#  'adorable',
#  'affusion',
#  'active',
#  'adjacent',
#  'adulation',
#  'ablaut',
#  'accused',
#  'aciculum',
#  'aalto',
#  'adrian',
#  'aerodrome',
#  'abruzzi',
#  'adduct',
#  'acanthus',
#  'affix',
#  'acaudal',
#  'ability',
#  'adamantine',
#  'acadian',
#  'adonis',
#  'abnormity',
#  'abrupt',
#  'aciniform',
#  'acroter',
#  'aboveboard',
#  'aerodontia',
#  'adjective',
#  'advantage',
#  'accession',
#  'aesthesia',
#  'aesop',
#  'admeasure',
#  'adult',
#  'affine',
#  'abysmal',
#  'abandon',
#  'abnormal',
#  'aftertime',
#  'aestivation',
#  'achromatic',
#  'adulterant',
#  'affirmative',
#  'abbasid',
#  'aerobiology',
#  'abnormality',
#  'aesculapius',
#  'actinolite',
#  'accountant',
#  'abukir',
#  'activator',
#  'accouplement',
#  'acanthoid',
#  'adipocere',
#  'abolition',
#  'accepted',
#  'acquaint',
#  'addington',
#  'aeroplane',
#  'achromic',
#  'advisable',
#  'aerial',
#  'adrenaline',
#  'acidulent',
#  'acidic',
#  'abortive',
#  'adamic',
#  'absent',
#  'above',
#  'acetal',
#  'advisory',
#  'acicula',
#  'achondrite',
#  'accordingly',
#  'acton',
#  'aeolotropic',
#  'afterburning',
#  'adjuvant',
#  'activate',
#  'afterbrain',
#  'acrylyl',
#  'acetylide',
#  'aboard',
#  'adjudicate',
#  'abject',
#  'aftercare',
#  'advocaat',
#  'academy',
#  'accessary',
#  'aerobiosis',
#  'aeromancy',
#  'aberdare',
#  'acclaim',
#  'aec',
#  'aflame',
#  'affright',
#  'absorption',
#  'activist',
#  'acclimatize',
#  'abuse',
#  'abalone',
#  'abydos',
#  'adactylous',
#  'afield',
#  'abstemious',
#  'acarpous',
#  'acclimate',
#  'accessory',
#  'absorbing',
#  'actinia',
#  'addle',
#  'adapa',
#  'aerothermodynamics',
#  'affable',
#  'affair',
#  'abstractionist',
#  'afterglow',
#  'abrade',
#  'abstruse',
#  'adamite',
#  'accounting',
#  'aeronautics',
#  'affluence',
#  'accomplish',
#  'adoration',
#  'abmho',
#  'abaddon',
#  'adjunction',
#  'acclivity',
#  'adherence',
#  'adonic',
#  'achieve',
#  'acquiescence',
#  'aconcagua',
#  'achernar',
#  'achaemenid',
#  'aetiology',
#  'affectation',
#  'abroad',
#  'abiding',
#  'termite',
#  'absinthe',
#  'abdominal',
#  'adana',
#  'acrylonitrile',
#  'acrolith',
#  'adiathermancy',
#  'acetanilide',
#  'accomplice',
#  'acetylene',
#  'actium',
#  'abadan',
#  'aeonian',
#  'abettor',
#  'acceleration',
#  'aerometer',
#  'afterbirth',
#  'abdominous',
#  'aerolite',
#  'aforementioned',
#  'acaleph',
#  'adherent',
#  'abm',
#  'abreact',
#  'absorptance',
#  'acoustic',
#  'abecedarium',
#  'abscise',
#  'adapt',
#  'admiral',
#  'acierate',
#  'abel',
#  'abirritant',
#  'aerotherapeutics',
#  'abelard',
#  'across',
#  'accidence',
#  'advert',
#  'a1',
#  'adige',
#  'actinouranium',
#  'accede',
#  'acerb',
#  'afterdamp',
#  'aeciospore',
#  'abidjan',
#  'acriflavine',
#  'affranchise',
#  'acknowledge',
#  'additament',
#  'accusation',
#  'aesculapian',
#  'abilene',
#  'lemon',
#  'advisee',
#  'affluent',
#  'absalom',
#  'advance',
#  'accidie',
#  'adventure',
#  'accommodative',
#  'aalst',
#  'adust',
#  'about',
#  'acropolis',
#  'admire',
#  'aam',
#  'abnaki',
#  'affirmatory',
#  'ac',
#  'aeschines',
#  'acarid',
#  'adoptive',
#  'affecting',
#  'aerodynamics',
#  'acrogen',
#  'acceptable',
#  'aerator',
#  'abortifacient',
#  'abnegate',
#  'abbreviation',
#  'afterlife',
#  'accelerando',
#  'abri',
#  'acetylate',
#  'aegrotat',
#  'aedile',
#  'addend',
#  'address',
#  'aalborg',
#  'acquiesce',
#  'achromaticity',
#  'aboral',
#  'abaxial',
#  'adigranth',
#  'absentminded',
#  'acceptance',
#  'afforest',
#  'adviser',
#  'adversary',
#  'abessive',
#  'aboulia',
#  'actionable',
#  'accoutre',
#  'adore',
#  'aerodonetics',
#  'aeroneurosis',
#  'acuate',
#  'absonant',
#  'adaptive',
#  'achromatism',
#  'accoucheur',
#  'abridgment',
#  'advocation',
#  'acinaciform',
#  'acquittance',
#  'adversaria',
#  'adaxial',
#  'accordance',
#  'affirm',
#  'adynamia',
#  'abide',
#  'adventurer',
#  'adventurous',
#  'aduwa',
#  'acme',
#  'accelerometer',
#  'administrative',
#  'achromat',
#  'aardwolf',
#  'accompany',
#  'advocacy',
#  'aculeus',
#  'acinus',
#  'accept',
#  'aftershaft',
#  'aestivate',
#  'accouterment',
#  'abbot',
#  'aeneous',
#  'advantageous',
#  'africanist',
#  'admass',
#  'addressee',
#  'adit',
#  'accumulator',
#  'adulterine',
#  'acaroid',
#  'aegyptus',
#  'melon',
#  'acupuncture',
#  'accompanyist',
#  'achaean',
#  'aether',
#  'affection',
#  'adductor',
#  'actinozoan',
#  'absorb',
#  'abolish',
#  'abutment',
#  'accommodating',
#  'aegeus',
#  'aeneas',
#  'actinomycosis',
#  'abate',
#  'accusal',
#  'abstraction',
#  'ademption',
#  'actinotherapy',
#  'adaptable',
#  'acrolein',
#  'aceldama',
#  'adjustment',
#  'aden',
#  'advertisement',
#  'abjure',
#  'aaronic',
#  'adieu',
#  'acaricide',
#  'aery',
#  'advertise',
#  'accipiter',
#  'acapulco',
#  'acarus',
#  'ablution',
#  'accelerate',
#  'afterimage',
#  'acis',
#  'afreet',
#  'acrobat',
#  'addlebrained',
#  'afterwards',
#  'administrate',
#  'aftermath',
#  'actinology',
#  'absolute',
#  'actin',
#  'advise',
#  'adenoma',
#  'advertence',
#  'acrostic',
#  'addendum',
#  'adduce',
#  'abdication',
#  'acrobatic',
#  'acidosis',
#  'acth',
#  'acanthocephalan',
#  'achlorhydria',
#  'acerate',
#  'aerogram',
#  'accouchement',
#  'advisedly',
#  'aba',
#  'adduction',
#  'aftereffect',
#  'abstractionism',
#  'aeolian',
#  'aerostat',
#  'adsorbent',
#  'accustomed',
#  'accommodation',
#  'adversity',
#  'acquiescent',
#  'add',
#  'act',
#  'abbreviate',
#  'adventist',
#  'aerosol',
#  'abeokuta',
#  'abbess',
#  'accentor',
#  'adjoining',
#  'adjourn',
#  'achromatin',
#  'abattoir',
#  'actomyosin',
#  'accuracy',
#  'afternoon',
#  'adenocarcinoma',
#  'adenoidectomy',
#  'actinometer',
#  'acidimetry',
#  'affray',
#  'afterclap',
#  'abhorrence',
#  'aeroscope',
#  'aftersensation',
#  'aeroballistics',
#  'according',
#  'ad',
#  'acetylcholine',
#  'adenoid',
#  'afresh',
#  'leak',
#  'adventitia',
#  'adenoidal',
#  'abiogenesis',
#  'aardvark',
#  'aerospace',
#  'acetous',
#  'acanthopterygian',
#  'abominate',
#  'affinitive',
#  'acotyledon',
#  'afflict',
#  'actualize',
#  'acutance',
#  'admonish',
#  'acquittal',
#  'abjuration',
#  'absinthism',
#  'affiliation',
#  'accordant',
#  'abulia',
#  'adventitious',
#  'admonitory',
#  'acuity',
#  'adagio',
#  'abyssal',
#  'afflux',
#  'af',
#  'actaeon',
#  'acetate',
#  'adios',
#  'adam',
#  'actable',
#  'adessive',
#  'adamant',
#  'affective',
#  'admittedly',
#  'aerograph',
#  'actinium',
#  'abb',
#  'acervate',
#  'accad',
#  'accessible',
#  'aerification',
#  'abstention',
#  'abductor',
#  'aetna',
#  'aesir',
#  'academic',
#  'adumbrate',
#  'aerate',
#  'adenectomy',
#  'aerie',
#  'abstract',
#  'aboriginal',
#  'aerugo',
#  'advertent',
#  'adjudication',
#  'aboveground',
#  'additional',
#  'adytum',
#  'affiche',
#  'accordion',
#  'admission',
#  'absorbance',
#  'aftergrowth',
#  'absurdity',
#  'abigail',
#  'addition',
#  'acceptor',
#  'adiaphorous',
#  'aflutter',
#  'meatier',
#  'adenitis',
#  'abvolt',
#  'acarology',
#  'abiogenetic',
#  'absorbent',
#  'acred',
#  'accepter',
#  'abacist',
#  'acetic',
#  'aeschylus',
#  'abbacy',
#  'acne',
#  'adventuress',
#  'accusatorial',
#  'abutilon',
#  'advent',
#  'acyl',
#  'affidavit',
#  'advice',
#  'accost',
#  'activism',
#  'affect',
#  'afb',
#  'abiotic',
#  'abhor',
#  'adrastus',
#  'aerography',
#  'african',
#  'adriatic',
#  'advanced',
#  'aalesund',
#  'affricate',
#  'adrenal',
#  'abduction',
#  'abingdon',
#  'aborticide',
#  'acanthous',
#  'administrator',
#  'aaron',
#  'adiaphorism',
#  'admissible',
#  'abutting',
#  'acquire',
#  'aborigine',
#  'affricative',
#  'adsorb',
#  'affectional',
#  'achromatize',
#  'adjectival',
#  'aeromechanic',
#  'affaire',
#  'acroterion',
#  'abase',
#  'abdicate',
#  'abloom',
#  'abirritate',
#  'acculturate',
#  'accidental',
#  'aedes',
#  'abode',
#  'adroit',
#  'adumbral',
#  'accipitrine',
#  'adjutant',
#  'acromegaly',
#  'adulterer',
#  'aarau',
#  'abranchiate',
#  'adornment',
#  'aficionado',
#  'acerbic',
#  'adulate',
#  'acoustician',
#  'advowson',
#  'acidify',
#  'actinic',
#  'abominable',
#  'aftertaste',
#  'ablepsia',
#  'aberration',
#  'aegis',
#  'afford',
#  'acnode',
#  'acosmism',
#  'abut',
#  'adz',
#  'ab',
#  'acute',
#  'acquaintance',
#  'advancement',
#  'adopt',
#  'adhibit',
#  'aeromarine',
#  'acknowledgment',
#  'afterburner',
#  'adopted',
#  'adequacy',
#  'achromatous',
#  'acephalous',
#  'acoustics',
#  'achondroplasia',
#  'affliction',
#  'adelaide',
#  'adler',
#  'adobe',
#  'abrasive',
#  'actor',
#  'accurate',
#  'able',
#  'abeam',
#  'accuse',
#  'adhesion',
#  'afrit',
#  'abortion',
#  'adulteress',
#  'accumbent',
#  'academia',
#  'admit',
#  'acquisitive',
#  'acaulescent',
#  'abet',
#  'actinon',
#  'afc',
#  'aborning',
#  'accouter',
#  'afferent',
#  'actual',
#  'abroach',
#  'adams',
#  'acid',
#  'accra',
#  'abysm',
#  'abduct',
#  'adularia',
#  'aerometry',
#  'abscissa',
#  'adze',
#  'absolution',
#  'absquatulate',
#  'aerobe',
#  'adulterous',
#  'achilles',
#  'academe',
#  'affiance',
#  'acrodrome',
#  'aeroembolism',
#  'abba',
#  'abaca',
#  'addict',
#  'acescent',
#  'abc',
#  'access',
#  'achates',
#  'abrogate',
#  'adventuresome',
#  'abed',
#  'abuttal',
#  'admixture',
#  'ado',
#  'aegospotami',
#  'acronym',
#  'acerose',
#  'admissive',
#  'achitophel',
#  'actuary',
#  'adaptation',
#  'afterward',
#  'absorbed',
#  'affairs',
#  'adjacency',
#  'admirable',
#  'advised',
#  'aerophyte',
#  'action',
#  'admittance',
#  'afire',
#  'accent',
#  'acculturize',
#  'accentual',
#  'aegaeon',
#  'afflatus',
#  'actinomorphic',
#  'africander',
#  'aestheticism',
#  'abracadabra',
#  'adhere',
#  'aerosphere',
#  'abrasion',
#  'adenovirus',
#  'aerometeorograph',
#  'accolade',
#  'abatis',
#  'abdomen',
#  'affenpinscher',
#  'aberrant',
#  'aestival',
#  'abiosis',
#  'abyss',
#  'abstergent',
#  'adminicle',
#  'afghan',
#  'aftershock',
#  'africa',
#  'adverbial',
#  'acidimeter',
#  'aerophobia',
#  'acidulate',
#  'accumulation',
#  'addiction',
#  'afternoons',
#  'adjunct',
#  'accountancy',
#  'abound',
#  'afoul',
#  'acrospire',
#  'reed',
#  'acetone',
#  'aforetime',
#  'absence',
#  'abomination',
#  'acacia',
#  'abib',
#  'aby',
#  'absenteeism',
#  'adolescent',
#  'aeolus',
#  'adversative',
#  'accretion',
#  'adenine',
#  'absolve',
#  'accord',
#  'aeriform',
#  'aeromechanics',
#  'aarhus',
#  'aalii',
#  'adenauer',
#  'adermin',
#  'abecedary',
#  'accusatory',
#  'acetum',
#  'acidophil',
#  'acetaldehyde',
#  'accompanist',
#  'abyssinia',
#  'aetolia',
#  'adamsite',
#  'affiliate',
#  'abraham',
#  'afore',
#  'acquisition',
#  'ace',
#  'acetabulum',
#  'affinity',
#  'abstinence',
#  'accursed',
#  'acceptant',
#  'abeyant',
#  'adowa',
#  'acting',
#  'abednego',
#  'adonai',
#  'ably',
#  'abduce',
#  'absolutely',
#  'abcoulomb',
#  'abradant',
#  'adenosine',
#  'aerobatics',
#  'addicted',
#  'actress',
#  'abbey',
#  'afebrile',
#  'accumulative',
#  'abort',
#  'abstriction',
#  'actinochemistry',
#  'accusative',
#  'adiabatic',
#  'accustom',
#  'acidity',
#  'acetometer',
#  'acanthaceous',
#  'aesthetic',
#  'acrylic',
#  'advertising',
#  'acadia',
#  'absurd',
#  'afar',
#  'absorbefacient',
#  'lake',
#  'accomplishment',
#  'adman',
#  'ablaze',
#  'adultery',
#  'acciaccatura',
#  'abruption',
#  'acerbate',
#  'acorn',
#  'acculturation',
#  'abampere',
#  'actinomycin',
#  'acclamation',
#  'abusive',
#  'abuttals',
#  'adept',
#  'actuate',
#  'afflictive',
#  'ablation',
#  'ache',
#  'acicular',
#  'aback',
#  'adnate',
#  'advocate',
#  'abraxas',
#  'afghani',
#  'adar',
#  'abscission',
#  'additory',
#  'acrid',
#  'abhorrent',
#  'acridine',
#  'adrenalin',
#  'acreage',
#  ...]

# %% [markdown]
# Observe the results; make sure the data has been successfully loaded.
# Then, run the map transformation:

# %%
tuples = words.map(lambda x: (''.join(sorted(list(x))), x))
tuples.collect()
# Out:
# [('aciimnoorsu', 'acrimonious'),
#  ('adeenory', 'aerodyne'),
#  ('aaaciirss', 'acariasis'),
#  ('aaclltuy', 'actually'),
#  ('aabmmosu', 'abomasum'),
#  ('aceehn', 'achene'),
#  ('abcesss', 'abscess'),
#  ('adnor', 'adorn'),
#  ('acceinrt', 'acentric'),
#  ('abeeenst', 'absentee'),
#  ('aaeefhrtt', 'afterheat'),
#  ('aabbdeeirtv', 'abbreviated'),
#  ('aft', 'aft'),
#  ('adfirt', 'adrift'),
#  ('aabdeorst', 'adsorbate'),
#  ('aceeimnqrtu', 'acquirement'),
#  ('acehnor', 'acheron'),
#  ('aacceelorrt', 'accelerator'),
#  ('abhmo', 'abohm'),
#  ('aaagru', 'aargau'),
#  ('afoot', 'afoot'),
#  ('aaeegn', 'aegean'),
#  ('acimnory', 'acrimony'),
#  ('aacilttuy', 'actuality'),
#  ('aeeiillop', 'aeolipile'),
#  ('aabcciorst', 'acrobatics'),
#  ('aacceinoptt', 'acceptation'),
#  ('aaffiln', 'affinal'),
#  ('adeein', 'aeneid'),
#  ('aciqtu', 'acquit'),
#  ('aaceeffinott', 'affectionate'),
#  ('aaafiknrs', 'afrikaans'),
#  ('aabdnntu', 'abundant'),
#  ('abcdentu', 'abducent'),
#  ('acdnoort', 'acrodont'),
#  ('aefghhoorttu', 'aforethought'),
#  ('aadeelrttu', 'adulterate'),
#  ('aceloty', 'acolyte'),
#  ('adnow', 'adown'),
#  ('aaabbilt', 'abbatial'),
#  ('aaddms', 'addams'),
#  ('aeeimtt', 'teatime'),
#  ('adeersv', 'adverse'),
#  ('abeel', 'abele'),
#  ('aaeinoorstt', 'aerostation'),
#  ('afor', 'afro'),
#  ('aacceimmnnopt', 'accompaniment'),
#  ('aadefr', 'afeard'),
#  ('aefghhortttu', 'afterthought'),
#  ('adeflorrtw', 'afterworld'),
#  ('aabelt', 'ablate'),
#  ('aaaceh', 'achaea'),
#  ('abcdnos', 'abscond'),
#  ('aabccelnotu', 'accountable'),
#  ('abceirty', 'acerbity'),
#  ('aaccooprrsu', 'acrocarpous'),
#  ('aaceiorsstt', 'aerostatics'),
#  ('aeghisstu', 'aegisthus'),
#  ('adjstu', 'adjust'),
#  ('acelty', 'acetyl'),
#  ('aacdeinqtu', 'acquainted'),
#  ('accnotu', 'account'),
#  ('aacefiinrz', 'africanize'),
#  ('aabcderstt', 'abstracted'),
#  ('abceior', 'aerobic'),
#  ('abbeorrs', 'absorber'),
#  ('aacdeeilmor', 'aeromedical'),
#  ('ademstu', 'admetus'),
#  ('acimnoor', 'acromion'),
#  ('aaceimntu', 'acuminate'),
#  ('aa', 'aa'),
#  ('aaefiknrr', 'afrikaner'),
#  ('acddeiitv', 'addictive'),
#  ('aacceinnottu', 'accentuation'),
#  ('a', 'a'),
#  ('aaabcdeeinr', 'abecedarian'),
#  ('accceenrst', 'accrescent'),
#  ('accdeint', 'accident'),
#  ('addegju', 'adjudge'),
#  ('aaffiinotx', 'affixation'),
#  ('aadeilnorttu', 'adulteration'),
#  ('aaceiorstt', 'aerostatic'),
#  ('aabchioopr', 'acrophobia'),
#  ('aabcsu', 'abacus'),
#  ('aaegin', 'aegina'),
#  ('aacceiltu', 'aciculate'),
#  ('aabddenno', 'abandoned'),
#  ('aacclru', 'accrual'),
#  ('aacilnr', 'acrilan'),
#  ('deer', 'deer'),
#  ('aaccdeiimms', 'academicism'),
#  ('aaffint', 'affiant'),
#  ('aacceelnrt', 'accelerant'),
#  ('aeehnoopr', 'aerophone'),
#  ('abehnry', 'abhenry'),
#  ('aabeemntt', 'abatement'),
#  ('aacdeeimt', 'acetamide'),
#  ('acemnu', 'acumen'),
#  ('aadeeemmnrstu', 'admeasurement'),
#  ('abdegir', 'abridge'),
#  ('aaccchor', 'accroach'),
#  ('aaberst', 'abreast'),
#  ('adeehisv', 'adhesive'),
#  ('aceeefiprt', 'afterpiece'),
#  ('acdiiiossttu', 'adscititious'),
#  ('adp', 'adp'),
#  ('aaafghinnst', 'afghanistan'),
#  ('aadeilnopr', 'adrianople'),
#  ('aaaccceiltt', 'acatalectic'),
#  ('acceru', 'accrue'),
#  ('abelnsty', 'absently'),
#  ('acehlosu', 'achelous'),
#  ('abcdins', 'abscind'),
#  ('aciittvy', 'activity'),
#  ('aaeiilrst', 'aerialist'),
#  ('acccdeiinooooprrrtt', 'adrenocorticotropic'),
#  ('accdeirt', 'accredit'),
#  ('adeeimnstv', 'advisement'),
#  ('aadddeelpt', 'addlepated'),
#  ('aegir', 'aegir'),
#  ('acfiimnort', 'actiniform'),
#  ('acdeefkrt', 'afterdeck'),
#  ('aacdehlmosuy', 'achlamydeous'),
#  ('aacdei', 'acedia'),
#  ('aadegiott', 'adagietto'),
#  ('abiinoorstt', 'abortionist'),
#  ('aceeehimntv', 'achievement'),
#  ('adeiimnrst', 'administer'),
#  ('acceert', 'accrete'),
#  ('aacceenttu', 'accentuate'),
#  ('aaceloprt', 'acropetal'),
#  ('aaddx', 'addax'),
#  ('aegloory', 'aerology'),
#  ('aabft', 'abaft'),
#  ('aceinot', 'aconite'),
#  ('aefiry', 'aerify'),
#  ('adder', 'adder'),
#  ('adejru', 'adjure'),
#  ('acdinoopt', 'actinopod'),
#  ('aaceeltu', 'aculeate'),
#  ('adijnot', 'adjoint'),
#  ('aacdilntu', 'acidulant'),
#  ('aadefiknrr', 'afrikander'),
#  ('aaceehillstty', 'aesthetically'),
#  ('abilmosstu', 'absolutism'),
#  ('aabbeiillnv', 'abbevillian'),
#  ('aeilos', 'aeolis'),
#  ('abuzz', 'abuzz'),
#  ('aaenortu', 'aeronaut'),
#  ('aadiimnort', 'admiration'),
#  ('aeor', 'aero'),
#  ('aabmp', 'abamp'),
#  ('aeno', 'aeon'),
#  ('aceilo', 'aeolic'),
#  ('adejmnnortu', 'adjournment'),
#  ('acdeeehiinnoptt', 'acetophenetidin'),
#  ('aadefgrrtu', 'afterguard'),
#  ('adeiops', 'adipose'),
#  ('acefity', 'acetify'),
#  ('aadfir', 'afraid'),
#  ('adimx', 'admix'),
#  ('abdeeenr', 'aberdeen'),
#  ('aaaccdeiimn', 'academician'),
#  ('adeffin', 'affined'),
#  ('aabceeny', 'abeyance'),
#  ('aefmorstt', 'aftermost'),
#  ('adiimnnoot', 'admonition'),
#  ('aabinst', 'abstain'),
#  ('abderv', 'adverb'),
#  ('aabttw', 'abwatt'),
#  ('aadiiimnnorstt', 'administration'),
#  ('aceehisstt', 'aesthetics'),
#  ('aaflot', 'afloat'),
#  ('aaaeghiopr', 'aerophagia'),
#  ('aefrt', 'after'),
#  ('addhlootu', 'adulthood'),
#  ('aaabdfr', 'abfarad'),
#  ('aadilmrty', 'admiralty'),
#  ('acdeinotv', 'advection'),
#  ('aadeprt', 'adapter'),
#  ('aabhs', 'abash'),
#  ('abiioprsttvy', 'absorptivity'),
#  ('acdeefft', 'affected'),
#  ('addeiitv', 'additive'),
#  ('abeklmos', 'abelmosk'),
#  ('adijno', 'adjoin'),
#  ('accdeeelnos', 'adolescence'),
#  ('aabdis', 'abdias'),
#  ('accdehilmops', 'accomplished'),
#  ('abdeforty', 'afterbody'),
#  ('aceimu', 'aecium'),
#  ('aaddeghoprrss', 'addressograph'),
#  ('abeils', 'abseil'),
#  ('aeffoosttu', 'affettuoso'),
#  ('adeimnrstuv', 'adventurism'),
#  ('aaccdemmoot', 'accommodate'),
#  ('aadeg', 'adage'),
#  ('addinos', 'addison'),
#  ('aadefiors', 'aforesaid'),
#  ('aacdeffin', 'affianced'),
#  ('aabcdennu', 'abundance'),
#  ('affnort', 'affront'),
#  ('aadeeqtu', 'adequate'),
#  ('acdilosuu', 'acidulous'),
#  ('acdiinoprst', 'adscription'),
#  ('aberttu', 'abutter'),
#  ('aciimnst', 'actinism'),
#  ('aaeeoprsu', 'aeropause'),
#  ('aacehn', 'aachen'),
#  ('aacilnt', 'actinal'),
#  ('aeeehstt', 'aesthete'),
#  ('aabdelor', 'adorable'),
#  ('affinosu', 'affusion'),
#  ('aceitv', 'active'),
#  ('aacdejnt', 'adjacent'),
#  ('aadilnotu', 'adulation'),
#  ('aabltu', 'ablaut'),
#  ('accdesu', 'accused'),
#  ('accilmuu', 'aciculum'),
#  ('aalot', 'aalto'),
#  ('aadinr', 'adrian'),
#  ('adeemoorr', 'aerodrome'),
#  ('abiruzz', 'abruzzi'),
#  ('acddtu', 'adduct'),
#  ('aachnstu', 'acanthus'),
#  ('affix', 'affix'),
#  ('aaacdlu', 'acaudal'),
#  ('abiilty', 'ability'),
#  ('aaadeimnnt', 'adamantine'),
#  ('aaacdin', 'acadian'),
#  ('adinos', 'adonis'),
#  ('abimnorty', 'abnormity'),
#  ('abprtu', 'abrupt'),
#  ('acfiimnor', 'aciniform'),
#  ('aceorrt', 'acroter'),
#  ('aabbdeoorv', 'aboveboard'),
#  ('aadeinoort', 'aerodontia'),
#  ('acdeeijtv', 'adjective'),
#  ('aaadegntv', 'advantage'),
#  ('acceinoss', 'accession'),
#  ('aaeehisst', 'aesthesia'),
#  ('aeops', 'aesop'),
#  ('aadeemrsu', 'admeasure'),
#  ('adltu', 'adult'),
#  ('aeffin', 'affine'),
#  ('aablmsy', 'abysmal'),
#  ('aabdnno', 'abandon'),
#  ('aablmnor', 'abnormal'),
#  ('aeefimrtt', 'aftertime'),
#  ('aaeiinosttv', 'aestivation'),
#  ('aacchimort', 'achromatic'),
#  ('aadelnrttu', 'adulterant'),
#  ('aaeffiimrtv', 'affirmative'),
#  ('aabbdis', 'abbasid'),
#  ('abegilooory', 'aerobiology'),
#  ('aabilmnorty', 'abnormality'),
#  ('aaceilpssuu', 'aesculapius'),
#  ('aceiilnott', 'actinolite'),
#  ('aaccnnottu', 'accountant'),
#  ('abikru', 'abukir'),
#  ('aaciorttv', 'activator'),
#  ('acceelmnoptu', 'accouplement'),
#  ('aacdhinot', 'acanthoid'),
#  ('acdeeiopr', 'adipocere'),
#  ('abiilnoot', 'abolition'),
#  ('accdeept', 'accepted'),
#  ('aacinqtu', 'acquaint'),
#  ('addginnot', 'addington'),
#  ('aaeelnopr', 'aeroplane'),
#  ('acchimor', 'achromic'),
#  ('aabdeilsv', 'advisable'),
#  ('aaeilr', 'aerial'),
#  ('aadeeilnnr', 'adrenaline'),
#  ('acdeilntu', 'acidulent'),
#  ('accdii', 'acidic'),
#  ('abeiortv', 'abortive'),
#  ('aacdim', 'adamic'),
#  ('abenst', 'absent'),
#  ('abeov', 'above'),
#  ('aacelt', 'acetal'),
#  ('adiorsvy', 'advisory'),
#  ('aaccilu', 'acicula'),
#  ('acdehinort', 'achondrite'),
#  ('accdgilnory', 'accordingly'),
#  ('acnot', 'acton'),
#  ('aceiloooprt', 'aeolotropic'),
#  ('abefginnrrtu', 'afterburning'),
#  ('aadjntuv', 'adjuvant'),
#  ('aaceittv', 'activate'),
#  ('aabefinrrt', 'afterbrain'),
#  ('acllryy', 'acrylyl'),
#  ('acdeeilty', 'acetylide'),
#  ('aabdor', 'aboard'),
#  ('aacddeijtu', 'adjudicate'),
#  ('abcejt', 'abject'),
#  ('aaceefrrt', 'aftercare'),
#  ('aaacdotv', 'advocaat'),
#  ('aacdemy', 'academy'),
#  ('aaccerssy', 'accessary'),
#  ('abeiioorss', 'aerobiosis'),
#  ('aacemnory', 'aeromancy'),
#  ('aabdeerr', 'aberdare'),
#  ('aaccilm', 'acclaim'),
#  ('ace', 'aec'),
#  ('aaeflm', 'aflame'),
#  ('affghirt', 'affright'),
#  ('abinooprst', 'absorption'),
#  ('aciisttv', 'activist'),
#  ('aacceiilmtz', 'acclimatize'),
#  ('abesu', 'abuse'),
#  ('aabelno', 'abalone'),
#  ('abdosy', 'abydos'),
#  ('aacdlostuy', 'adactylous'),
#  ('adefil', 'afield'),
#  ('abeimosstu', 'abstemious'),
#  ('aacoprsu', 'acarpous'),
#  ('aacceilmt', 'acclimate'),
#  ('acceorssy', 'accessory'),
#  ('abbginors', 'absorbing'),
#  ('aaciint', 'actinia'),
#  ('addel', 'addle'),
#  ('aaadp', 'adapa'),
#  ('aacdeehimmnoorrsty', 'aerothermodynamics'),
#  ('aabeffl', 'affable'),
#  ('aaffir', 'affair'),
#  ('aabciinorssttt', 'abstractionist'),
#  ('aefglortw', 'afterglow'),
#  ('aabder', 'abrade'),
#  ('abersstu', 'abstruse'),
#  ('aadeimt', 'adamite'),
#  ('accginnotu', 'accounting'),
#  ('aaceinorstu', 'aeronautics'),
#  ('aceefflnu', 'affluence'),
#  ('acchilmops', 'accomplish'),
#  ('aadinoort', 'adoration'),
#  ('abhmo', 'abmho'),
#  ('aabddno', 'abaddon'),
#  ('acdijnnotu', 'adjunction'),
#  ('acciiltvy', 'acclivity'),
#  ('acdeeehnr', 'adherence'),
#  ('acdino', 'adonic'),
#  ('aceehiv', 'achieve'),
#  ('accceeeinqsu', 'acquiescence'),
#  ('aaaccgnou', 'aconcagua'),
#  ('aacehnrr', 'achernar'),
#  ('aacdeehimn', 'achaemenid'),
#  ('aegilooty', 'aetiology'),
#  ('aaceffinott', 'affectation'),
#  ('aabdor', 'abroad'),
#  ('abdgiin', 'abiding'),
#  ('eeimrtt', 'termite'),
#  ('abehinst', 'absinthe'),
#  ('aabdilmno', 'abdominal'),
#  ('aaadn', 'adana'),
#  ('aceiillnorrty', 'acrylonitrile'),
#  ('achilort', 'acrolith'),
#  ('aaacdehimnrty', 'adiathermancy'),
#  ('aacdeeiilnt', 'acetanilide'),
#  ('accceilmop', 'accomplice'),
#  ('aceeelnty', 'acetylene'),
#  ('acimtu', 'actium'),
#  ('aaabdn', 'abadan'),
#  ('aaeinno', 'aeonian'),
#  ('abeortt', 'abettor'),
#  ('aacceeilnort', 'acceleration'),
#  ('aeeemorrt', 'aerometer'),
#  ('abefhirrtt', 'afterbirth'),
#  ('abdimnoosu', 'abdominous'),
#  ('aeeilort', 'aerolite'),
#  ('adeeefimnnoort', 'aforementioned'),
#  ('aacehlp', 'acaleph'),
#  ('adeehnrt', 'adherent'),
#  ('abm', 'abm'),
#  ('aabcert', 'abreact'),
#  ('aabcenoprst', 'absorptance'),
#  ('acciostu', 'acoustic'),
#  ('aabcdeeimru', 'abecedarium'),
#  ('abceiss', 'abscise'),
#  ('aadpt', 'adapt'),
#  ('aadilmr', 'admiral'),
#  ('aaceeirt', 'acierate'),
#  ('abel', 'abel'),
#  ('aabiinrrtt', 'abirritant'),
#  ('aaceeehioprrsttu', 'aerotherapeutics'),
#  ('aabdelr', 'abelard'),
#  ('acorss', 'across'),
#  ('acccdeein', 'accidence'),
#  ('adertv', 'advert'),
#  ('1a', 'a1'),
#  ('adegi', 'adige'),
#  ('aaciimnnortuu', 'actinouranium'),
#  ('accdee', 'accede'),
#  ('abcer', 'acerb'),
#  ('aadefmprt', 'afterdamp'),
#  ('aceeiooprs', 'aeciospore'),
#  ('aabdijn', 'abidjan'),
#  ('aacefiilnrv', 'acriflavine'),
#  ('aaceffhinrs', 'affranchise'),
#  ('acdeegklnow', 'acknowledge'),
#  ('aaddeimntt', 'additament'),
#  ('aaccinostu', 'accusation'),
#  ('aaaceilnpsu', 'aesculapian'),
#  ('abeeiln', 'abilene'),
#  ('elmno', 'lemon'),
#  ('adeeisv', 'advisee'),
#  ('aefflntu', 'affluent'),
#  ('aablmos', 'absalom'),
#  ('aacdenv', 'advance'),
#  ('accdeii', 'accidie'),
#  ('adeenrtuv', 'adventure'),
#  ('aaccdeimmootv', 'accommodative'),
#  ('aalst', 'aalst'),
#  ('adstu', 'adust'),
#  ('abotu', 'about'),
#  ('acilooprs', 'acropolis'),
#  ('adeimr', 'admire'),
#  ('aam', 'aam'),
#  ('aabikn', 'abnaki'),
#  ('aaffimorrty', 'affirmatory'),
#  ('ac', 'ac'),
#  ('aceehinss', 'aeschines'),
#  ('aacdir', 'acarid'),
#  ('adeioptv', 'adoptive'),
#  ('aceffgint', 'affecting'),
#  ('aacdeimnorsy', 'aerodynamics'),
#  ('acegnor', 'acrogen'),
#  ('aabcceelpt', 'acceptable'),
#  ('aaeorrt', 'aerator'),
#  ('aabcefiinortt', 'abortifacient'),
#  ('aabeegnt', 'abnegate'),
#  ('aabbeiinortv', 'abbreviation'),
#  ('aeeffilrt', 'afterlife'),
#  ('aaccdeelnor', 'accelerando'),
#  ('abir', 'abri'),
#  ('aaceeltty', 'acetylate'),
#  ('aaegortt', 'aegrotat'),
#  ('adeeil', 'aedile'),
#  ('addden', 'addend'),
#  ('adderss', 'address'),
#  ('aabglor', 'aalborg'),
#  ('acceeiqsu', 'acquiesce'),
#  ('aacchiimortty', 'achromaticity'),
#  ('aablor', 'aboral'),
#  ('aaabilx', 'abaxial'),
#  ('aadghinrt', 'adigranth'),
#  ('abddeeimnnst', 'absentminded'),
#  ('aaccceenpt', 'acceptance'),
#  ('aefforst', 'afforest'),
#  ('adeirsv', 'adviser'),
#  ('aaderrsvy', 'adversary'),
#  ('abeeissv', 'abessive'),
#  ('aabilou', 'aboulia'),
#  ('aabceilnot', 'actionable'),
#  ('acceortu', 'accoutre'),
#  ('adeor', 'adore'),
#  ('acdeeinoorst', 'aerodonetics'),
#  ('aeeinoorrssu', 'aeroneurosis'),
#  ('aacetu', 'acuate'),
#  ('aabnnost', 'absonant'),
#  ('aadeiptv', 'adaptive'),
#  ('aachimmorst', 'achromatism'),
#  ('acccehoruu', 'accoucheur'),
#  ('abdegimnrt', 'abridgment'),
#  ('aacdinootv', 'advocation'),
#  ('aaccfiimnor', 'acinaciform'),
#  ('aacceinqttu', 'acquittance'),
#  ('aaadeirrsv', 'adversaria'),
#  ('aaadilx', 'adaxial'),
#  ('aacccdenor', 'accordance'),
#  ('affimr', 'affirm'),
#  ('aaadimny', 'adynamia'),
#  ('abdei', 'abide'),
#  ('adeenrrtuv', 'adventurer'),
#  ('adenorstuuv', 'adventurous'),
#  ('aaduw', 'aduwa'),
#  ('acem', 'acme'),
#  ('acceeeelmorrt', 'accelerometer'),
#  ('aadeiiimnrsttv', 'administrative'),
#  ('aachmort', 'achromat'),
#  ('aadflorw', 'aardwolf'),
#  ('aaccmnopy', 'accompany'),
#  ('aaccdovy', 'advocacy'),
#  ('acelsuu', 'aculeus'),
#  ('acinsu', 'acinus'),
#  ('accept', 'accept'),
#  ('aaeffhrstt', 'aftershaft'),
#  ('aaeeisttv', 'aestivate'),
#  ('acceemnorttu', 'accouterment'),
#  ('abbot', 'abbot'),
#  ('aeenosu', 'aeneous'),
#  ('aaadegnostuv', 'advantageous'),
#  ('aacfiinrst', 'africanist'),
#  ('aadmss', 'admass'),
#  ('addeeerss', 'addressee'),
#  ('adit', 'adit'),
#  ('aacclmortuu', 'accumulator'),
#  ('adeeilnrtu', 'adulterine'),
#  ('aacdior', 'acaroid'),
#  ('aegpstuy', 'aegyptus'),
#  ('elmno', 'melon'),
#  ('accenprtuuu', 'acupuncture'),
#  ('aaccimnopsty', 'accompanyist'),
#  ('aaacehn', 'achaean'),
#  ('aeehrt', 'aether'),
#  ('aceffinot', 'affection'),
#  ('acddortu', 'adductor'),
#  ('aacinnootz', 'actinozoan'),
#  ('abbors', 'absorb'),
#  ('abhilos', 'abolish'),
#  ('abemnttu', 'abutment'),
#  ('aaccdgimmnoot', 'accommodating'),
#  ('aeegsu', 'aegeus'),
#  ('aaeens', 'aeneas'),
#  ('acciimnoossty', 'actinomycosis'),
#  ('aabet', 'abate'),
#  ('aacclsu', 'accusal'),
#  ('aabcinorstt', 'abstraction'),
#  ('adeimnopt', 'ademption'),
#  ('aacehinoprtty', 'actinotherapy'),
#  ('aaabdelpt', 'adaptable'),
#  ('aceilnor', 'acrolein'),
#  ('aaacdelm', 'aceldama'),
#  ('adejmnsttu', 'adjustment'),
#  ('aden', 'aden'),
#  ('adeeeimnrsttv', 'advertisement'),
#  ('abejru', 'abjure'),
#  ('aacinor', 'aaronic'),
#  ('adeiu', 'adieu'),
#  ('aaccdeiir', 'acaricide'),
#  ('aery', 'aery'),
#  ('adeeirstv', 'advertise'),
#  ('acceiiprt', 'accipiter'),
#  ('aacclopu', 'acapulco'),
#  ('aacrsu', 'acarus'),
#  ('abilnotu', 'ablution'),
#  ('aacceeelrt', 'accelerate'),
#  ('aaeefgimrt', 'afterimage'),
#  ('acis', 'acis'),
#  ('aeefrt', 'afreet'),
#  ('aabcort', 'acrobat'),
#  ('aabdddeeilnr', 'addlebrained'),
#  ('aadefrrstw', 'afterwards'),
#  ('aadeiimnrstt', 'administrate'),
#  ('aaefhmrtt', 'aftermath'),
#  ('acgilnooty', 'actinology'),
#  ('abelostu', 'absolute'),
#  ('acint', 'actin'),
#  ('adeisv', 'advise'),
#  ('aademno', 'adenoma'),
#  ('acdeeenrtv', 'advertence'),
#  ('acciorst', 'acrostic'),
#  ('adddemnu', 'addendum'),
#  ('acddeu', 'adduce'),
#  ('aabcdiinot', 'abdication'),
#  ('aabcciort', 'acrobatic'),
#  ('acdiioss', 'acidosis'),
#  ('acht', 'acth'),
#  ('aaaaccehhlnnopt', 'acanthocephalan'),
#  ('aacdhhilorry', 'achlorhydria'),
#  ('aaceert', 'acerate'),
#  ('aaegmorr', 'aerogram'),
#  ('accceehmnotu', 'accouchement'),
#  ('addeilsvy', 'advisedly'),
#  ('aab', 'aba'),
#  ('acddinotu', 'adduction'),
#  ('aceeefffrtt', 'aftereffect'),
#  ('aabciimnorsstt', 'abstractionism'),
#  ('aaeilno', 'aeolian'),
#  ('aaeorstt', 'aerostat'),
#  ('abdenorst', 'adsorbent'),
#  ('accdemostu', 'accustomed'),
#  ('aaccdimmnooot', 'accommodation'),
#  ('adeirstvy', 'adversity'),
#  ('acceeinqstu', 'acquiescent'),
#  ('add', 'add'),
#  ('act', 'act'),
#  ('aabbeeirtv', 'abbreviate'),
#  ('adeinsttv', 'adventist'),
#  ('aeloors', 'aerosol'),
#  ('aabekotu', 'abeokuta'),
#  ('abbess', 'abbess'),
#  ('accenort', 'accentor'),
#  ('adgiijnno', 'adjoining'),
#  ('adjnoru', 'adjourn'),
#  ('aachimnort', 'achromatin'),
#  ('aabiortt', 'abattoir'),
#  ('acimnoosty', 'actomyosin'),
#  ('aacccruy', 'accuracy'),
#  ('aefnnoort', 'afternoon'),
#  ('aaaccdeimnnoor', 'adenocarcinoma'),
#  ('acddeeimnooty', 'adenoidectomy'),
#  ('aceeimnortt', 'actinometer'),
#  ('acdeiimrty', 'acidimetry'),
#  ('aaffry', 'affray'),
#  ('aaceflprt', 'afterclap'),
#  ('abceehnorr', 'abhorrence'),
#  ('aceeooprs', 'aeroscope'),
#  ('aaeefinnorsstt', 'aftersensation'),
#  ('aabceiillorsst', 'aeroballistics'),
#  ('accdginor', 'according'),
#  ('ad', 'ad'),
#  ('acceehillnoty', 'acetylcholine'),
#  ('addeino', 'adenoid'),
#  ('aefhrs', 'afresh'),
#  ('aekl', 'leak'),
#  ('aadeiinttv', 'adventitia'),
#  ('aaddeilno', 'adenoidal'),
#  ('abeegiinoss', 'abiogenesis'),
#  ('aaadkrrv', 'aardvark'),
#  ('aaceeoprs', 'aerospace'),
#  ('aceostu', 'acetous'),
#  ('aaaceghinnoprtty', 'acanthopterygian'),
#  ('aabeimnot', 'abominate'),
#  ('aeffiiintv', 'affinitive'),
#  ('acdelnooty', 'acotyledon'),
#  ('acffilt', 'afflict'),
#  ('aaceiltuz', 'actualize'),
#  ('aaccentu', 'acutance'),
#  ('adhimnos', 'admonish'),
#  ('aacilqttu', 'acquittal'),
#  ('aabijnortu', 'abjuration'),
#  ('abhiimnsst', 'absinthism'),
#  ('aaffiiilnot', 'affiliation'),
#  ('aaccdnort', 'accordant'),
#  ('aabilu', 'abulia'),
#  ('adeiinosttuv', 'adventitious'),
#  ('adimnoorty', 'admonitory'),
#  ('acituy', 'acuity'),
#  ('aadgio', 'adagio'),
#  ('aablssy', 'abyssal'),
#  ('afflux', 'afflux'),
#  ('af', 'af'),
#  ('aacenot', 'actaeon'),
#  ('aaceett', 'acetate'),
#  ('adios', 'adios'),
#  ('aadm', 'adam'),
#  ('aabcelt', 'actable'),
#  ('adeeissv', 'adessive'),
#  ('aaadmnt', 'adamant'),
#  ('aceeffitv', 'affective'),
#  ('addeilmtty', 'admittedly'),
#  ('aaeghoprr', 'aerograph'),
#  ('aciimntu', 'actinium'),
#  ('abb', 'abb'),
#  ('aaceertv', 'acervate'),
#  ('aaccd', 'accad'),
#  ('abcceeilss', 'accessible'),
#  ('aacefiiinort', 'aerification'),
#  ('abeinnostt', 'abstention'),
#  ('abcdortu', 'abductor'),
#  ('aaent', 'aetna'),
#  ('aeirs', 'aesir'),
#  ('aaccdeim', 'academic'),
#  ('aabdemrtu', 'adumbrate'),
#  ('aaeert', 'aerate'),
#  ('acdeemnoty', 'adenectomy'),
#  ('aeeir', 'aerie'),
#  ('aabcrstt', 'abstract'),
#  ('aabgiilnor', 'aboriginal'),
#  ('aegoru', 'aerugo'),
#  ('adeenrttv', 'advertent'),
#  ('aacddiijnotu', 'adjudication'),
#  ('abdegnooruv', 'aboveground'),
#  ('aaddiilnot', 'additional'),
#  ('admtuy', 'adytum'),
#  ('aceffhi', 'affiche'),
#  ('accdinoor', 'accordion'),
#  ('adiimnoss', 'admission'),
#  ('aabbcenors', 'absorbance'),
#  ('aefghorrttw', 'aftergrowth'),
#  ('abdirstuy', 'absurdity'),
#  ('aabgiil', 'abigail'),
#  ('addiinot', 'addition'),
#  ('acceoprt', 'acceptor'),
#  ('aadhiooprsu', 'adiaphorous'),
#  ('aeflrttu', 'aflutter'),
#  ('aeeimrt', 'meatier'),
#  ('adeiinst', 'adenitis'),
#  ('ablotv', 'abvolt'),
#  ('aacgloory', 'acarology'),
#  ('abceegiinot', 'abiogenetic'),
#  ('abbenorst', 'absorbent'),
#  ('acder', 'acred'),
#  ('acceeprt', 'accepter'),
#  ('aabcist', 'abacist'),
#  ('acceit', 'acetic'),
#  ('acehlssuy', 'aeschylus'),
#  ('aabbcy', 'abbacy'),
#  ('acen', 'acne'),
#  ('adeenrsstuv', 'adventuress'),
#  ('aaaccilorstu', 'accusatorial'),
#  ('abilnotu', 'abutilon'),
#  ('adentv', 'advent'),
#  ('acly', 'acyl'),
#  ('aadffiitv', 'affidavit'),
#  ('acdeiv', 'advice'),
#  ('accost', 'accost'),
#  ('aciimstv', 'activism'),
#  ('acefft', 'affect'),
#  ('abf', 'afb'),
#  ('abciiot', 'abiotic'),
#  ('abhor', 'abhor'),
#  ('aadrsstu', 'adrastus'),
#  ('aaeghoprry', 'aerography'),
#  ('aacfinr', 'african'),
#  ('aacdiirt', 'adriatic'),
#  ('aacddenv', 'advanced'),
#  ('aadelnsu', 'aalesund'),
#  ('aaceffirt', 'affricate'),
#  ('aadelnr', 'adrenal'),
#  ('abcdinotu', 'abduction'),
#  ('abdginno', 'abingdon'),
#  ('abcdeiiort', 'aborticide'),
#  ('aachnostu', 'acanthous'),
#  ('aadiimnorrstt', 'administrator'),
#  ('aanor', 'aaron'),
#  ('aadhiimoprs', 'adiaphorism'),
#  ('abdeiilmss', 'admissible'),
#  ('abginttu', 'abutting'),
#  ('aceiqru', 'acquire'),
#  ('abegiinor', 'aborigine'),
#  ('aaceffiirtv', 'affricative'),
#  ('abdors', 'adsorb'),
#  ('aaceffilnot', 'affectional'),
#  ('aacehimortz', 'achromatize'),
#  ('aacdeijltv', 'adjectival'),
#  ('aacceehimnor', 'aeromechanic'),
#  ('aaeffir', 'affaire'),
#  ('aceinoorrt', 'acroterion'),
#  ('aabes', 'abase'),
#  ('aabcdeit', 'abdicate'),
#  ('ablmoo', 'abloom'),
#  ('aabeiirrtt', 'abirritate'),
#  ('aaccelrttuu', 'acculturate'),
#  ('aaccdeilnt', 'accidental'),
#  ('adees', 'aedes'),
#  ('abdeo', 'abode'),
#  ('adiort', 'adroit'),
#  ('aabdlmru', 'adumbral'),
#  ('acceiiinprt', 'accipitrine'),
#  ('aadjnttu', 'adjutant'),
#  ('aaceglmory', 'acromegaly'),
#  ('adeelrrtu', 'adulterer'),
#  ('aaaru', 'aarau'),
#  ('aaabcehinrt', 'abranchiate'),
#  ('ademnnort', 'adornment'),
#  ('aacdfiinoo', 'aficionado'),
#  ('abcceir', 'acerbic'),
#  ('aadeltu', 'adulate'),
#  ('aacciinostu', 'acoustician'),
#  ('adnoosvw', 'advowson'),
#  ('acdfiiy', 'acidify'),
#  ('acciint', 'actinic'),
#  ('aabbeilmno', 'abominable'),
#  ('aaeefrsttt', 'aftertaste'),
#  ('aabeilps', 'ablepsia'),
#  ('aabeinorrt', 'aberration'),
#  ('aegis', 'aegis'),
#  ('adffor', 'afford'),
#  ('acdeno', 'acnode'),
#  ('acimmoss', 'acosmism'),
#  ('abtu', 'abut'),
#  ('adz', 'adz'),
#  ('ab', 'ab'),
#  ('acetu', 'acute'),
#  ('aaacceinnqtu', 'acquaintance'),
#  ('aacdeemnntv', 'advancement'),
#  ('adopt', 'adopt'),
#  ('abdhiit', 'adhibit'),
#  ('aaeeimnorr', 'aeromarine'),
#  ('acdeegklmnnotw', 'acknowledgment'),
#  ('abeefnrrrtu', 'afterburner'),
#  ('addeopt', 'adopted'),
#  ('aacdequy', 'adequacy'),
#  ('aachmoorstu', 'achromatous'),
#  ('aacehlopsu', 'acephalous'),
#  ('acciosstu', 'acoustics'),
#  ('aaacdhilnooprs', 'achondroplasia'),
#  ('acffiilnot', 'affliction'),
#  ('aaddeeil', 'adelaide'),
#  ('adelr', 'adler'),
#  ('abdeo', 'adobe'),
#  ('aabeirsv', 'abrasive'),
#  ('acort', 'actor'),
#  ('aaccertu', 'accurate'),
#  ('abel', 'able'),
#  ('aabem', 'abeam'),
#  ('accesu', 'accuse'),
#  ('adehinos', 'adhesion'),
#  ('afirt', 'afrit'),
#  ('abinoort', 'abortion'),
#  ('adeelrsstu', 'adulteress'),
#  ('abccemntu', 'accumbent'),
#  ('aaacdeim', 'academia'),
#  ('adimt', 'admit'),
#  ('aceiiiqstuv', 'acquisitive'),
#  ('aacceelnstu', 'acaulescent'),
#  ('abet', 'abet'),
#  ('acinnot', 'actinon'),
#  ('acf', 'afc'),
#  ('abginnor', 'aborning'),
#  ('acceortu', 'accouter'),
#  ('aeeffnrt', 'afferent'),
#  ('aacltu', 'actual'),
#  ('aabchor', 'abroach'),
#  ('aadms', 'adams'),
#  ('acdi', 'acid'),
#  ('aaccr', 'accra'),
#  ('abmsy', 'abysm'),
#  ('abcdtu', 'abduct'),
#  ('aaadilru', 'adularia'),
#  ('aeemorrty', 'aerometry'),
#  ('aabcisss', 'abscissa'),
#  ('adez', 'adze'),
#  ('abilnoostu', 'absolution'),
#  ('aaabelqsttuu', 'absquatulate'),
#  ('abeeor', 'aerobe'),
#  ('adelorstuu', 'adulterous'),
#  ('acehills', 'achilles'),
#  ('aacdeem', 'academe'),
#  ('aaceffin', 'affiance'),
#  ('acdemoorr', 'acrodrome'),
#  ('abeeilmmoors', 'aeroembolism'),
#  ('aabb', 'abba'),
#  ('aaabc', 'abaca'),
#  ('acddit', 'addict'),
#  ('acceenst', 'acescent'),
#  ('abc', 'abc'),
#  ('access', 'access'),
#  ('aacehst', 'achates'),
#  ('aabegort', 'abrogate'),
#  ('adeeemnorstuv', 'adventuresome'),
#  ('abde', 'abed'),
#  ('aablttu', 'abuttal'),
#  ('adeimrtux', 'admixture'),
#  ('ado', 'ado'),
#  ('aaegimoopst', 'aegospotami'),
#  ('acmnory', 'acronym'),
#  ('aceeors', 'acerose'),
#  ('adeiimssv', 'admissive'),
#  ('acehhilopt', 'achitophel'),
#  ('aacrtuy', 'actuary'),
#  ('aaadinoptt', 'adaptation'),
#  ('aadefrrtw', 'afterward'),
#  ('abbdeors', 'absorbed'),
#  ('aaffirs', 'affairs'),
#  ('aaccdejny', 'adjacency'),
#  ('aabdeilmr', 'admirable'),
#  ('addeisv', 'advised'),
#  ('aeehoprty', 'aerophyte'),
#  ('acinot', 'action'),
#  ('aacdeimntt', 'admittance'),
#  ('aefir', 'afire'),
#  ('accent', 'accent'),
#  ('acceilrtuuz', 'acculturize'),
#  ('aaccelntu', 'accentual'),
#  ('aaeegno', 'aegaeon'),
#  ('aafflstu', 'afflatus'),
#  ('acchiimnooprt', 'actinomorphic'),
#  ('aacdefinrr', 'africander'),
#  ('aceehiimsstt', 'aestheticism'),
#  ('aaaaabbcdrr', 'abracadabra'),
#  ('adeehr', 'adhere'),
#  ('aeeehoprrs', 'aerosphere'),
#  ('aabinors', 'abrasion'),
#  ('adeinorsuv', 'adenovirus'),
#  ('aaeeeghmoooprrrt', 'aerometeorograph'),
#  ('aaccdelo', 'accolade'),
#  ('aabist', 'abatis'),
#  ('abdemno', 'abdomen'),
#  ('aceeffhinnprs', 'affenpinscher'),
#  ('aabenrrt', 'aberrant'),
#  ('aaeilstv', 'aestival'),
#  ('abiioss', 'abiosis'),
#  ('abssy', 'abyss'),
#  ('abeegnrstt', 'abstergent'),
#  ('acdeiilmn', 'adminicle'),
#  ('aafghn', 'afghan'),
#  ('acefhkorst', 'aftershock'),
#  ('aacfir', 'africa'),
#  ('aabdeilrv', 'adverbial'),
#  ('acdeeiimrt', 'acidimeter'),
#  ('aabehioopr', 'aerophobia'),
#  ('aacdeiltu', 'acidulate'),
#  ('aaccilmnotuu', 'accumulation'),
#  ('acddiinot', 'addiction'),
#  ('aefnnoorst', 'afternoons'),
#  ('acdjntu', 'adjunct'),
#  ('aacccnnotuy', 'accountancy'),
#  ('abdnou', 'abound'),
#  ('aflou', 'afoul'),
#  ('aceioprrs', 'acrospire'),
#  ('deer', 'reed'),
#  ('aceenot', 'acetone'),
#  ('aeefimort', 'aforetime'),
#  ('abceens', 'absence'),
#  ('aabiimnnoot', 'abomination'),
#  ('aaacci', 'acacia'),
#  ('abbi', 'abib'),
#  ('aby', 'aby'),
#  ('abeeeimnsst', 'absenteeism'),
#  ('acdeelnost', 'adolescent'),
#  ('aelosu', 'aeolus'),
#  ('aadeeirstvv', 'adversative'),
#  ('acceinort', 'accretion'),
#  ('adeeinn', 'adenine'),
#  ('abelosv', 'absolve'),
#  ('accdor', 'accord'),
#  ('aefimorr', 'aeriform'),
#  ('aacceehimnors', 'aeromechanics'),
#  ('aahrsu', 'aarhus'),
#  ('aaiil', 'aalii'),
#  ('aadeenru', 'adenauer'),
#  ('adeimnr', 'adermin'),
#  ('aabcdeery', 'abecedary'),
#  ('aaccorstuy', 'accusatory'),
#  ('acemtu', 'acetum'),
#  ('acdhiilop', 'acidophil'),
#  ('aacddeeehlty', 'acetaldehyde'),
#  ('aaccimnopst', 'accompanist'),
#  ('aabiinssy', 'abyssinia'),
#  ('aaeilot', 'aetolia'),
#  ('aadeimst', 'adamsite'),
#  ('aaeffiilt', 'affiliate'),
#  ('aaabhmr', 'abraham'),
#  ('aefor', 'afore'),
#  ('aciiinoqstu', 'acquisition'),
#  ('ace', 'ace'),
#  ('aabcelmtuu', 'acetabulum'),
#  ('affiinty', 'affinity'),
#  ('abceeinnst', 'abstinence'),
#  ('accdersu', 'accursed'),
#  ('aaccenptt', 'acceptant'),
#  ('aabenty', 'abeyant'),
#  ('aadow', 'adowa'),
#  ('acgint', 'acting'),
#  ('abdeegno', 'abednego'),
#  ('aadino', 'adonai'),
#  ('ably', 'ably'),
#  ('abcdeu', 'abduce'),
#  ('abellostuy', 'absolutely'),
#  ('abbclmoou', 'abcoulomb'),
#  ('aaabdnrt', 'abradant'),
#  ('adeeinnos', 'adenosine'),
#  ('aabceiorst', 'aerobatics'),
#  ('acdddeit', 'addicted'),
#  ('acersst', 'actress'),
#  ('abbey', 'abbey'),
#  ('abeefilr', 'afebrile'),
#  ('aacceilmtuuv', 'accumulative'),
#  ('abort', 'abort'),
#  ('abciinorstt', 'abstriction'),
#  ('accehiimnorstty', 'actinochemistry'),
#  ('aacceistuv', 'accusative'),
#  ('aaabcdiit', 'adiabatic'),
#  ('accmostu', 'accustom'),
#  ('acdiity', 'acidity'),
#  ('aceeemortt', 'acetometer'),
#  ('aaaccehnostu', 'acanthaceous'),
#  ('aceehistt', 'aesthetic'),
#  ('accilry', 'acrylic'),
#  ('adegiinrstv', 'advertising'),
#  ('aaacdi', 'acadia'),
#  ('abdrsu', 'absurd'),
#  ('aafr', 'afar'),
#  ('aabbceefinorst', 'absorbefacient'),
#  ('aekl', 'lake'),
#  ('accehilmmnopst', 'accomplishment'),
#  ('aadmn', 'adman'),
#  ('aabelz', 'ablaze'),
#  ('adelrtuy', 'adultery'),
#  ('aaaaccccirtu', 'acciaccatura'),
#  ('abinoprtu', 'abruption'),
#  ('aabceert', 'acerbate'),
#  ('acnor', 'acorn'),
#  ('aaccilnorttuu', 'acculturation'),
#  ('aabeempr', 'abampere'),
#  ('acciimnnoty', 'actinomycin'),
#  ('aaaccilmnot', 'acclamation'),
#  ('abeisuv', 'abusive'),
#  ('aablsttu', 'abuttals'),
#  ('adept', 'adept'),
#  ('aacettu', 'actuate'),
#  ('aceffiiltv', 'afflictive'),
#  ('aabilnot', 'ablation'),
#  ('aceh', 'ache'),
#  ('aaccilru', 'acicular'),
#  ('aabck', 'aback'),
#  ('aadent', 'adnate'),
#  ('aacdeotv', 'advocate'),
#  ('aaabrsx', 'abraxas'),
#  ('aafghin', 'afghani'),
#  ('aadr', 'adar'),
#  ('abciinosss', 'abscission'),
#  ('addiorty', 'additory'),
#  ('acdir', 'acrid'),
#  ('abehnorrt', 'abhorrent'),
#  ('acdeiinr', 'acridine'),
#  ('aadeilnnr', 'adrenalin'),
#  ('aaceegr', 'acreage'),
#  ...]

# %% [markdown]
# Then, run the groupByKey (the rough equivalent to Hadoop’s « shuffle »):

# %%
grouped = tuples.groupByKey().mapValues(lambda x: list(x))
grouped.collect()
# Out:
# [('adeenory', ['aerodyne']),
#  ('aceehn', ['achene']),
#  ('abcesss', ['abscess']),
#  ('adnor', ['adorn']),
#  ('adfirt', ['adrift']),
#  ('aabdeorst', ['adsorbate']),
#  ('aceeimnqrtu', ['acquirement']),
#  ('acehnor', ['acheron']),
#  ('abhmo', ['abohm', 'abmho']),
#  ('aaagru', ['aargau']),
#  ('aacilttuy', ['actuality']),
#  ('aabcciorst', ['acrobatics']),
#  ('aacceinoptt', ['acceptation']),
#  ('aaffiln', ['affinal']),
#  ('adeein', ['aeneid']),
#  ('aciqtu', ['acquit']),
#  ('aaafiknrs', ['afrikaans']),
#  ('aabdnntu', ['abundant']),
#  ('abcdentu', ['abducent']),
#  ('acdnoort', ['acrodont']),
#  ('aceloty', ['acolyte']),
#  ('aaabbilt', ['abbatial']),
#  ('aaddms', ['addams']),
#  ('aeeimtt', ['teatime']),
#  ('adeersv', ['adverse']),
#  ('aadefr', ['afeard']),
#  ('aefghhortttu', ['afterthought']),
#  ('aaaceh', ['achaea']),
#  ('aabccelnotu', ['accountable']),
#  ('abceirty', ['acerbity']),
#  ('aaccooprrsu', ['acrocarpous']),
#  ('adjstu', ['adjust']),
#  ('accnotu', ['account']),
#  ('aacefiinrz', ['africanize']),
#  ('aacdeeilmor', ['aeromedical']),
#  ('ademstu', ['admetus']),
#  ('aaceimntu', ['acuminate']),
#  ('aa', ['aa']),
#  ('aaabcdeeinr', ['abecedarian']),
#  ('accdeint', ['accident']),
#  ('aaffiinotx', ['affixation']),
#  ('aaceiorstt', ['aerostatic']),
#  ('aabchioopr', ['acrophobia']),
#  ('aabcsu', ['abacus']),
#  ('aaegin', ['aegina']),
#  ('aacceiltu', ['aciculate']),
#  ('aacclru', ['accrual']),
#  ('aacilnr', ['acrilan']),
#  ('aacceelnrt', ['accelerant']),
#  ('aeehnoopr', ['aerophone']),
#  ('abehnry', ['abhenry']),
#  ('aabeemntt', ['abatement']),
#  ('aacdeeimt', ['acetamide']),
#  ('acemnu', ['acumen']),
#  ('abdegir', ['abridge']),
#  ('adeehisv', ['adhesive']),
#  ('aceeefiprt', ['afterpiece']),
#  ('acdiiiossttu', ['adscititious']),
#  ('adp', ['adp']),
#  ('aaafghinnst', ['afghanistan']),
#  ('aadeilnopr', ['adrianople']),
#  ('aaaccceiltt', ['acatalectic']),
#  ('abelnsty', ['absently']),
#  ('acehlosu', ['achelous']),
#  ('abcdins', ['abscind']),
#  ('aciittvy', ['activity']),
#  ('aaeiilrst', ['aerialist']),
#  ('acccdeiinooooprrrtt', ['adrenocorticotropic']),
#  ('acdeefkrt', ['afterdeck']),
#  ('aacdei', ['acedia']),
#  ('abiinoorstt', ['abortionist']),
#  ('aceeehimntv', ['achievement']),
#  ('adeiimnrst', ['administer']),
#  ('aacceenttu', ['accentuate']),
#  ('aaceloprt', ['acropetal']),
#  ('aaddx', ['addax']),
#  ('aegloory', ['aerology']),
#  ('aceinot', ['aconite']),
#  ('adder', ['adder']),
#  ('acdinoopt', ['actinopod']),
#  ('aaceehillstty', ['aesthetically']),
#  ('aeor', ['aero']),
#  ('aeno', ['aeon']),
#  ('aceilo', ['aeolic']),
#  ('aadfir', ['afraid']),
#  ('adimx', ['admix']),
#  ('aefmorstt', ['aftermost']),
#  ('aabinst', ['abstain']),
#  ('aceehisstt', ['aesthetics']),
#  ('aaaeghiopr', ['aerophagia']),
#  ('aefrt', ['after']),
#  ('aadilmrty', ['admiralty']),
#  ('acdeinotv', ['advection']),
#  ('aadeprt', ['adapter']),
#  ('aabhs', ['abash']),
#  ('acdeefft', ['affected']),
#  ('addeiitv', ['additive']),
#  ('accdeeelnos', ['adolescence']),
#  ('aceimu', ['aecium']),
#  ('aaddeghoprrss', ['addressograph']),
#  ('aeffoosttu', ['affettuoso']),
#  ('aadeg', ['adage']),
#  ('addinos', ['addison']),
#  ('affnort', ['affront']),
#  ('acdilosuu', ['acidulous']),
#  ('acdiinoprst', ['adscription']),
#  ('aciimnst', ['actinism']),
#  ('aabdelor', ['adorable']),
#  ('affinosu', ['affusion']),
#  ('aceitv', ['active']),
#  ('aacdejnt', ['adjacent']),
#  ('accilmuu', ['aciculum']),
#  ('aalot', ['aalto']),
#  ('aadinr', ['adrian']),
#  ('abiruzz', ['abruzzi']),
#  ('aaadeimnnt', ['adamantine']),
#  ('abimnorty', ['abnormity']),
#  ('abprtu', ['abrupt']),
#  ('aabbdeoorv', ['aboveboard']),
#  ('acdeeijtv', ['adjective']),
#  ('acceinoss', ['accession']),
#  ('aeops', ['aesop']),
#  ('aadeemrsu', ['admeasure']),
#  ('adltu', ['adult']),
#  ('aablmnor', ['abnormal']),
#  ('aeefimrtt', ['aftertime']),
#  ('aaeiinosttv', ['aestivation']),
#  ('aacchimort', ['achromatic']),
#  ('aaeffiimrtv', ['affirmative']),
#  ('abikru', ['abukir']),
#  ('aaciorttv', ['activator']),
#  ('aacdhinot', ['acanthoid']),
#  ('acdeeiopr', ['adipocere']),
#  ('abiilnoot', ['abolition']),
#  ('aacinqtu', ['acquaint']),
#  ('aaeilr', ['aerial']),
#  ('aadeeilnnr', ['adrenaline']),
#  ('acdeilntu', ['acidulent']),
#  ('accdii', ['acidic']),
#  ('aacdim', ['adamic']),
#  ('abenst', ['absent']),
#  ('abeov', ['above']),
#  ('aaccilu', ['acicula']),
#  ('accdgilnory', ['accordingly']),
#  ('acnot', ['acton']),
#  ('aceiloooprt', ['aeolotropic']),
#  ('abefginnrrtu', ['afterburning']),
#  ('aadjntuv', ['adjuvant']),
#  ('aabefinrrt', ['afterbrain']),
#  ('acllryy', ['acrylyl']),
#  ('acdeeilty', ['acetylide']),
#  ('aaacdotv', ['advocaat']),
#  ('aaccerssy', ['accessary']),
#  ('abeiioorss', ['aerobiosis']),
#  ('aabdeerr', ['aberdare']),
#  ('ace', ['aec', 'ace']),
#  ('aaeflm', ['aflame']),
#  ('affghirt', ['affright']),
#  ('abinooprst', ['absorption']),
#  ('aciisttv', ['activist']),
#  ('aacceiilmtz', ['acclimatize']),
#  ('abesu', ['abuse']),
#  ('aabelno', ['abalone']),
#  ('abdosy', ['abydos']),
#  ('aacoprsu', ['acarpous']),
#  ('aaadp', ['adapa']),
#  ('aacdeehimmnoorrsty', ['aerothermodynamics']),
#  ('aabeffl', ['affable']),
#  ('abersstu', ['abstruse']),
#  ('aceefflnu', ['affluence']),
#  ('aadinoort', ['adoration']),
#  ('acdijnnotu', ['adjunction']),
#  ('acdeeehnr', ['adherence']),
#  ('aceehiv', ['achieve']),
#  ('aacdeehimn', ['achaemenid']),
#  ('aegilooty', ['aetiology']),
#  ('aaceffinott', ['affectation']),
#  ('abdgiin', ['abiding']),
#  ('achilort', ['acrolith']),
#  ('accceilmop', ['accomplice']),
#  ('acimtu', ['actium']),
#  ('aaabdn', ['abadan']),
#  ('aaeinno', ['aeonian']),
#  ('aeeilort', ['aerolite']),
#  ('adeeefimnnoort', ['aforementioned']),
#  ('adeehnrt', ['adherent']),
#  ('aabcert', ['abreact']),
#  ('aabcenoprst', ['absorptance']),
#  ('acciostu', ['acoustic']),
#  ('abceiss', ['abscise']),
#  ('abel', ['abel', 'able']),
#  ('aabiinrrtt', ['abirritant']),
#  ('aaceeehioprrsttu', ['aerotherapeutics']),
#  ('aabdelr', ['abelard']),
#  ('1a', ['a1']),
#  ('aaciimnnortuu', ['actinouranium']),
#  ('abcer', ['acerb']),
#  ('aceeiooprs', ['aeciospore']),
#  ('aabdijn', ['abidjan']),
#  ('aaceffhinrs', ['affranchise']),
#  ('acdeegklnow', ['acknowledge']),
#  ('aaaceilnpsu', ['aesculapian']),
#  ('abeeiln', ['abilene']),
#  ('adeeisv', ['advisee']),
#  ('aablmos', ['absalom']),
#  ('accdeii', ['accidie']),
#  ('aaccdeimmootv', ['accommodative']),
#  ('abotu', ['about']),
#  ('adeimr', ['admire']),
#  ('aam', ['aam']),
#  ('adeioptv', ['adoptive']),
#  ('acegnor', ['acrogen']),
#  ('aabcceelpt', ['acceptable']),
#  ('aaeorrt', ['aerator']),
#  ('aabcefiinortt', ['abortifacient']),
#  ('aabeegnt', ['abnegate']),
#  ('aabbeiinortv', ['abbreviation']),
#  ('aeeffilrt', ['afterlife']),
#  ('aaceeltty', ['acetylate']),
#  ('aaegortt', ['aegrotat']),
#  ('addden', ['addend']),
#  ('acceeiqsu', ['acquiesce']),
#  ('aaabilx', ['abaxial']),
#  ('aadghinrt', ['adigranth']),
#  ('abddeeimnnst', ['absentminded']),
#  ('aaderrsvy', ['adversary']),
#  ('abeeissv', ['abessive']),
#  ('aabilou', ['aboulia']),
#  ('aabceilnot', ['actionable']),
#  ('adeor', ['adore']),
#  ('aacetu', ['acuate']),
#  ('aabnnost', ['absonant']),
#  ('acccehoruu', ['accoucheur']),
#  ('aaccfiimnor', ['acinaciform']),
#  ('affimr', ['affirm']),
#  ('abdei', ['abide']),
#  ('adeenrrtuv', ['adventurer']),
#  ('aachmort', ['achromat']),
#  ('aaccmnopy', ['accompany']),
#  ('aaccdovy', ['advocacy']),
#  ('acelsuu', ['aculeus']),
#  ('aaeeisttv', ['aestivate']),
#  ('aacfiinrst', ['africanist']),
#  ('aadmss', ['admass']),
#  ('adit', ['adit']),
#  ('adeeilnrtu', ['adulterine']),
#  ('aacdior', ['acaroid']),
#  ('accenprtuuu', ['acupuncture']),
#  ('aaccimnopsty', ['accompanyist']),
#  ('aceffinot', ['affection']),
#  ('abbors', ['absorb']),
#  ('aaccdgimmnoot', ['accommodating']),
#  ('aeegsu', ['aegeus']),
#  ('aaeens', ['aeneas']),
#  ('acciimnoossty', ['actinomycosis']),
#  ('aacclsu', ['accusal']),
#  ('aabcinorstt', ['abstraction']),
#  ('aaabdelpt', ['adaptable']),
#  ('aden', ['aden']),
#  ('adeiu', ['adieu']),
#  ('aaccdeiir', ['acaricide']),
#  ('aery', ['aery']),
#  ('adeeirstv', ['advertise']),
#  ('acceiiprt', ['accipiter']),
#  ('acis', ['acis']),
#  ('aadefrrstw', ['afterwards']),
#  ('aadeiimnrstt', ['administrate']),
#  ('acgilnooty', ['actinology']),
#  ('adeisv', ['advise']),
#  ('aademno', ['adenoma']),
#  ('acddeu', ['adduce']),
#  ('acdiioss', ['acidosis']),
#  ('acht', ['acth']),
#  ('aacdhhilorry', ['achlorhydria']),
#  ('accceehmnotu', ['accouchement']),
#  ('aab', ['aba']),
#  ('aabciimnorsstt', ['abstractionism']),
#  ('aaeilno', ['aeolian']),
#  ('aaeorstt', ['aerostat']),
#  ('abdenorst', ['adsorbent']),
#  ('accdemostu', ['accustomed']),
#  ('acceeinqstu', ['acquiescent']),
#  ('act', ['act']),
#  ('aabekotu', ['abeokuta']),
#  ('abbess', ['abbess']),
#  ('accenort', ['accentor']),
#  ('aachimnort', ['achromatin']),
#  ('aabiortt', ['abattoir']),
#  ('aacccruy', ['accuracy']),
#  ('acddeeimnooty', ['adenoidectomy']),
#  ('aceeimnortt', ['actinometer']),
#  ('aaffry', ['affray']),
#  ('aaceflprt', ['afterclap']),
#  ('abceehnorr', ['abhorrence']),
#  ('aceeooprs', ['aeroscope']),
#  ('aabceiillorsst', ['aeroballistics']),
#  ('acceehillnoty', ['acetylcholine']),
#  ('aefhrs', ['afresh']),
#  ('aadeiinttv', ['adventitia']),
#  ('aaddeilno', ['adenoidal']),
#  ('aaadkrrv', ['aardvark']),
#  ('aaccdnort', ['accordant']),
#  ('aabilu', ['abulia']),
#  ('adimnoorty', ['admonitory']),
#  ('acituy', ['acuity']),
#  ('aablssy', ['abyssal']),
#  ('af', ['af']),
#  ('aaceett', ['acetate']),
#  ('aadm', ['adam']),
#  ('aaadmnt', ['adamant']),
#  ('addeilmtty', ['admittedly']),
#  ('aciimntu', ['actinium']),
#  ('aaccd', ['accad']),
#  ('abcceeilss', ['accessible']),
#  ('abeinnostt', ['abstention']),
#  ('aaent', ['aetna']),
#  ('aaccdeim', ['academic']),
#  ('aaeert', ['aerate']),
#  ('acdeemnoty', ['adenectomy']),
#  ('aeeir', ['aerie']),
#  ('aabgiilnor', ['aboriginal']),
#  ('aacddiijnotu', ['adjudication']),
#  ('abdegnooruv', ['aboveground']),
#  ('admtuy', ['adytum']),
#  ('abdirstuy', ['absurdity']),
#  ('aabgiil', ['abigail']),
#  ('addiinot', ['addition']),
#  ('aeflrttu', ['aflutter']),
#  ('aeeimrt', ['meatier']),
#  ('abbenorst', ['absorbent']),
#  ('acceeprt', ['accepter']),
#  ('aabcist', ['abacist']),
#  ('acceit', ['acetic']),
#  ('acen', ['acne']),
#  ('adeenrsstuv', ['adventuress']),
#  ('acly', ['acyl']),
#  ('acdeiv', ['advice']),
#  ('accost', ['accost']),
#  ('aciimstv', ['activism']),
#  ('acefft', ['affect']),
#  ('abhor', ['abhor']),
#  ('aaeghoprry', ['aerography']),
#  ('aacddenv', ['advanced']),
#  ('abcdinotu', ['abduction']),
#  ('abdginno', ['abingdon']),
#  ('aadiimnorrstt', ['administrator']),
#  ('aanor', ['aaron']),
#  ('aceiqru', ['acquire']),
#  ('abegiinor', ['aborigine']),
#  ('aaceffiirtv', ['affricative']),
#  ('abdors', ['adsorb']),
#  ('aacdeijltv', ['adjectival']),
#  ('aacceehimnor', ['aeromechanic']),
#  ('aaeffir', ['affaire']),
#  ('aceinoorrt', ['acroterion']),
#  ('aabes', ['abase']),
#  ('aabeiirrtt', ['abirritate']),
#  ('aaccelrttuu', ['acculturate']),
#  ('aadjnttu', ['adjutant']),
#  ('aacdfiinoo', ['aficionado']),
#  ('abcceir', ['acerbic']),
#  ('adnoosvw', ['advowson']),
#  ('acciint', ['actinic']),
#  ('aabbeilmno', ['abominable']),
#  ('aabeilps', ['ablepsia']),
#  ('aabeinorrt', ['aberration']),
#  ('acdeno', ['acnode']),
#  ('abtu', ['abut']),
#  ('ab', ['ab']),
#  ('acetu', ['acute']),
#  ('aaacceinnqtu', ['acquaintance']),
#  ('aacdeemnntv', ['advancement']),
#  ('adopt', ['adopt']),
#  ('abdhiit', ['adhibit']),
#  ('aaeeimnorr', ['aeromarine']),
#  ('acdeegklmnnotw', ['acknowledgment']),
#  ('addeopt', ['adopted']),
#  ('aacdequy', ['adequacy']),
#  ('aacehlopsu', ['acephalous']),
#  ('acciosstu', ['acoustics']),
#  ('aaacdhilnooprs', ['achondroplasia']),
#  ('acffiilnot', ['affliction']),
#  ('adelr', ['adler']),
#  ('aabeirsv', ['abrasive']),
#  ('aaccertu', ['accurate']),
#  ('afirt', ['afrit']),
#  ('adeelrsstu', ['adulteress']),
#  ('abccemntu', ['accumbent']),
#  ('adimt', ['admit']),
#  ('aceiiiqstuv', ['acquisitive']),
#  ('aacceelnstu', ['acaulescent']),
#  ('acinnot', ['actinon']),
#  ('aadms', ['adams']),
#  ('abcdtu', ['abduct']),
#  ('aaadilru', ['adularia']),
#  ('aabcisss', ['abscissa']),
#  ('adez', ['adze']),
#  ('abilnoostu', ['absolution']),
#  ('aaabelqsttuu', ['absquatulate']),
#  ('adelorstuu', ['adulterous']),
#  ('acehills', ['achilles']),
#  ('aabb', ['abba']),
#  ('aaabc', ['abaca']),
#  ('acceenst', ['acescent']),
#  ('abc', ['abc']),
#  ('aacehst', ['achates']),
#  ('aabegort', ['abrogate']),
#  ('adeimrtux', ['admixture']),
#  ('ado', ['ado']),
#  ('acmnory', ['acronym']),
#  ('aceeors', ['acerose']),
#  ('adeiimssv', ['admissive']),
#  ('aacrtuy', ['actuary']),
#  ('aadefrrtw', ['afterward']),
#  ('aaffirs', ['affairs']),
#  ('acinot', ['action']),
#  ('aacdeimntt', ['admittance']),
#  ('accent', ['accent']),
#  ('acceilrtuuz', ['acculturize']),
#  ('aaccelntu', ['accentual']),
#  ('aafflstu', ['afflatus']),
#  ('adeehr', ['adhere']),
#  ('aabinors', ['abrasion']),
#  ('aaccdelo', ['accolade']),
#  ('abdemno', ['abdomen']),
#  ('aaeilstv', ['aestival']),
#  ('abssy', ['abyss']),
#  ('abeegnrstt', ['abstergent']),
#  ('acdeiilmn', ['adminicle']),
#  ('aafghn', ['afghan']),
#  ('acefhkorst', ['aftershock']),
#  ('aacfir', ['africa']),
#  ('aabdeilrv', ['adverbial']),
#  ('aabehioopr', ['aerophobia']),
#  ('aacdeiltu', ['acidulate']),
#  ('aaccilmnotuu', ['accumulation']),
#  ('acddiinot', ['addiction']),
#  ('aefnnoorst', ['afternoons']),
#  ('aceioprrs', ['acrospire']),
#  ('aeefimort', ['aforetime']),
#  ('abceens', ['absence']),
#  ('aaacci', ['acacia']),
#  ('abbi', ['abib']),
#  ('aelosu', ['aeolus']),
#  ('aadeeirstvv', ['adversative']),
#  ('aefimorr', ['aeriform']),
#  ('aacceehimnors', ['aeromechanics']),
#  ('aaiil', ['aalii']),
#  ('aadeenru', ['adenauer']),
#  ('aaccorstuy', ['accusatory']),
#  ('aacddeeehlty', ['acetaldehyde']),
#  ('aaccimnopst', ['accompanist']),
#  ('aabiinssy', ['abyssinia']),
#  ('aaeffiilt', ['affiliate']),
#  ('aefor', ['afore']),
#  ('aciiinoqstu', ['acquisition']),
#  ('aabcelmtuu', ['acetabulum']),
#  ('abceeinnst', ['abstinence']),
#  ('accdersu', ['accursed']),
#  ('aadow', ['adowa']),
#  ('abdeegno', ['abednego']),
#  ('ably', ['ably']),
#  ('abcdeu', ['abduce']),
#  ('abbclmoou', ['abcoulomb']),
#  ('aaabdnrt', ['abradant']),
#  ('aabceiorst', ['aerobatics']),
#  ('acersst', ['actress']),
#  ('abbey', ['abbey']),
#  ('abort', ['abort']),
#  ('abciinorstt', ['abstriction']),
#  ('aacceistuv', ['accusative']),
#  ('acdiity', ['acidity']),
#  ('aceehistt', ['aesthetic']),
#  ('accilry', ['acrylic']),
#  ('adegiinrstv', ['advertising']),
#  ('aaacdi', ['acadia']),
#  ('abdrsu', ['absurd']),
#  ('aafr', ['afar']),
#  ('aabbceefinorst', ['absorbefacient']),
#  ('accehilmmnopst', ['accomplishment']),
#  ('aaaaccccirtu', ['acciaccatura']),
#  ('acnor', ['acorn']),
#  ('aabeempr', ['abampere']),
#  ('aablsttu', ['abuttals']),
#  ('adept', ['adept']),
#  ('aacettu', ['actuate']),
#  ('aabilnot', ['ablation']),
#  ('aaccilru', ['acicular']),
#  ('aadent', ['adnate']),
#  ('aafghin', ['afghani']),
#  ('abciinosss', ['abscission']),
#  ('abehnorrt', ['abhorrent']),
#  ('aaceegr', ['acreage']),
#  ('aabeiltv', ['ablative']),
#  ('acceeimnotty', ['actinomycete']),
#  ('adeforrtw', ['afterword']),
#  ('acer', ['acre']),
#  ('aabceinort', ['abreaction']),
#  ('acccily', ['acyclic']),
#  ('acdiinot', ['actinoid']),
#  ('aciimnoorsu', ['acrimonious']),
#  ('aaaciirss', ['acariasis']),
#  ('aaclltuy', ['actually']),
#  ('aabmmosu', ['abomasum']),
#  ('acceinrt', ['acentric']),
#  ('abeeenst', ['absentee']),
#  ('aaeefhrtt', ['afterheat']),
#  ('aabbdeeirtv', ['abbreviated']),
#  ('aft', ['aft']),
#  ('aacceelorrt', ['accelerator']),
#  ('afoot', ['afoot']),
#  ('aaeegn', ['aegean']),
#  ('acimnory', ['acrimony']),
#  ('aeeiillop', ['aeolipile']),
#  ('aaceeffinott', ['affectionate']),
#  ('aefghhoorttu', ['aforethought']),
#  ('aadeelrttu', ['adulterate']),
#  ('adnow', ['adown']),
#  ('abeel', ['abele']),
#  ('aaeinoorstt', ['aerostation']),
#  ('afor', ['afro']),
#  ('aacceimmnnopt', ['accompaniment']),
#  ('adeflorrtw', ['afterworld']),
#  ('aabelt', ['ablate']),
#  ('abcdnos', ['abscond']),
#  ('aaceiorsstt', ['aerostatics']),
#  ('aeghisstu', ['aegisthus']),
#  ('acelty', ['acetyl']),
#  ('aacdeinqtu', ['acquainted']),
#  ('aabcderstt', ['abstracted']),
#  ('abceior', ['aerobic']),
#  ('abbeorrs', ['absorber']),
#  ('acimnoor', ['acromion']),
#  ('aaefiknrr', ['afrikaner']),
#  ('acddeiitv', ['addictive']),
#  ('aacceinnottu', ['accentuation']),
#  ('a', ['a']),
#  ('accceenrst', ['accrescent']),
#  ('addegju', ['adjudge']),
#  ('aadeilnorttu', ['adulteration']),
#  ('aabddenno', ['abandoned']),
#  ('deer', ['deer', 'reed']),
#  ('aaccdeiimms', ['academicism']),
#  ('aaffint', ['affiant']),
#  ('aadeeemmnrstu', ['admeasurement']),
#  ('aaccchor', ['accroach']),
#  ('aaberst', ['abreast']),
#  ('acceru', ['accrue']),
#  ('accdeirt', ['accredit']),
#  ('adeeimnstv', ['advisement']),
#  ('aadddeelpt', ['addlepated']),
#  ('aegir', ['aegir']),
#  ('acfiimnort', ['actiniform']),
#  ('aacdehlmosuy', ['achlamydeous']),
#  ('aadegiott', ['adagietto']),
#  ('acceert', ['accrete']),
#  ('aabft', ['abaft']),
#  ('aefiry', ['aerify']),
#  ('adejru', ['adjure']),
#  ('aaceeltu', ['aculeate']),
#  ('adijnot', ['adjoint']),
#  ('aacdilntu', ['acidulant']),
#  ('aadefiknrr', ['afrikander']),
#  ('abilmosstu', ['absolutism']),
#  ('aabbeiillnv', ['abbevillian']),
#  ('aeilos', ['aeolis']),
#  ('abuzz', ['abuzz']),
#  ('aaenortu', ['aeronaut']),
#  ('aadiimnort', ['admiration']),
#  ('aabmp', ['abamp']),
#  ('adejmnnortu', ['adjournment']),
#  ('acdeeehiinnoptt', ['acetophenetidin']),
#  ('aadefgrrtu', ['afterguard']),
#  ('adeiops', ['adipose']),
#  ('acefity', ['acetify']),
#  ('abdeeenr', ['aberdeen']),
#  ('aaaccdeiimn', ['academician']),
#  ('adeffin', ['affined']),
#  ('aabceeny', ['abeyance']),
#  ('adiimnnoot', ['admonition']),
#  ('abderv', ['adverb']),
#  ('aabttw', ['abwatt']),
#  ('aadiiimnnorstt', ['administration']),
#  ('aaflot', ['afloat']),
#  ('addhlootu', ['adulthood']),
#  ('aaabdfr', ['abfarad']),
#  ('abiioprsttvy', ['absorptivity']),
#  ('abeklmos', ['abelmosk']),
#  ('adijno', ['adjoin']),
#  ('aabdis', ['abdias']),
#  ('accdehilmops', ['accomplished']),
#  ('abdeforty', ['afterbody']),
#  ('abeils', ['abseil']),
#  ('adeimnrstuv', ['adventurism']),
#  ('aaccdemmoot', ['accommodate']),
#  ('aadefiors', ['aforesaid']),
#  ('aacdeffin', ['affianced']),
#  ('aabcdennu', ['abundance']),
#  ('aadeeqtu', ['adequate']),
#  ('aberttu', ['abutter']),
#  ('aaeeoprsu', ['aeropause']),
#  ('aacehn', ['aachen']),
#  ('aacilnt', ['actinal']),
#  ('aeeehstt', ['aesthete']),
#  ('aadilnotu', ['adulation']),
#  ('aabltu', ['ablaut']),
#  ('accdesu', ['accused']),
#  ('adeemoorr', ['aerodrome']),
#  ('acddtu', ['adduct']),
#  ('aachnstu', ['acanthus']),
#  ('affix', ['affix']),
#  ('aaacdlu', ['acaudal']),
#  ('abiilty', ['ability']),
#  ('aaacdin', ['acadian']),
#  ('adinos', ['adonis']),
#  ('acfiimnor', ['aciniform']),
#  ('aceorrt', ['acroter']),
#  ('aadeinoort', ['aerodontia']),
#  ('aaadegntv', ['advantage']),
#  ('aaeehisst', ['aesthesia']),
#  ('aeffin', ['affine']),
#  ('aablmsy', ['abysmal']),
#  ('aabdnno', ['abandon']),
#  ('aadelnrttu', ['adulterant']),
#  ('aabbdis', ['abbasid']),
#  ('abegilooory', ['aerobiology']),
#  ('aabilmnorty', ['abnormality']),
#  ('aaceilpssuu', ['aesculapius']),
#  ('aceiilnott', ['actinolite']),
#  ('aaccnnottu', ['accountant']),
#  ('acceelmnoptu', ['accouplement']),
#  ('accdeept', ['accepted']),
#  ('addginnot', ['addington']),
#  ('aaeelnopr', ['aeroplane']),
#  ('acchimor', ['achromic']),
#  ('aabdeilsv', ['advisable']),
#  ('abeiortv', ['abortive']),
#  ('aacelt', ['acetal']),
#  ('adiorsvy', ['advisory']),
#  ('acdehinort', ['achondrite']),
#  ('aaceittv', ['activate']),
#  ('aabdor', ['aboard', 'abroad']),
#  ('aacddeijtu', ['adjudicate']),
#  ('abcejt', ['abject']),
#  ('aaceefrrt', ['aftercare']),
#  ('aacdemy', ['academy']),
#  ('aacemnory', ['aeromancy']),
#  ('aaccilm', ['acclaim']),
#  ('aacdlostuy', ['adactylous']),
#  ('adefil', ['afield']),
#  ('abeimosstu', ['abstemious']),
#  ('aacceilmt', ['acclimate']),
#  ('acceorssy', ['accessory']),
#  ('abbginors', ['absorbing']),
#  ('aaciint', ['actinia']),
#  ('addel', ['addle']),
#  ('aaffir', ['affair']),
#  ('aabciinorssttt', ['abstractionist']),
#  ('aefglortw', ['afterglow']),
#  ('aabder', ['abrade']),
#  ('aadeimt', ['adamite']),
#  ('accginnotu', ['accounting']),
#  ('aaceinorstu', ['aeronautics']),
#  ('acchilmops', ['accomplish']),
#  ('aabddno', ['abaddon']),
#  ('acciiltvy', ['acclivity']),
#  ('acdino', ['adonic']),
#  ('accceeeinqsu', ['acquiescence']),
#  ('aaaccgnou', ['aconcagua']),
#  ('aacehnrr', ['achernar']),
#  ('eeimrtt', ['termite']),
#  ('abehinst', ['absinthe']),
#  ('aabdilmno', ['abdominal']),
#  ('aaadn', ['adana']),
#  ('aceiillnorrty', ['acrylonitrile']),
#  ('aaacdehimnrty', ['adiathermancy']),
#  ('aacdeeiilnt', ['acetanilide']),
#  ('aceeelnty', ['acetylene']),
#  ('abeortt', ['abettor']),
#  ('aacceeilnort', ['acceleration']),
#  ('aeeemorrt', ['aerometer']),
#  ('abefhirrtt', ['afterbirth']),
#  ('abdimnoosu', ['abdominous']),
#  ('aacehlp', ['acaleph']),
#  ('abm', ['abm']),
#  ('aabcdeeimru', ['abecedarium']),
#  ('aadpt', ['adapt']),
#  ('aadilmr', ['admiral']),
#  ('aaceeirt', ['acierate']),
#  ('acorss', ['across']),
#  ('acccdeein', ['accidence']),
#  ('adertv', ['advert']),
#  ('adegi', ['adige']),
#  ('accdee', ['accede']),
#  ('aadefmprt', ['afterdamp']),
#  ('aacefiilnrv', ['acriflavine']),
#  ('aaddeimntt', ['additament']),
#  ('aaccinostu', ['accusation']),
#  ('elmno', ['lemon', 'melon']),
#  ('aefflntu', ['affluent']),
#  ('aacdenv', ['advance']),
#  ('adeenrtuv', ['adventure']),
#  ('aalst', ['aalst']),
#  ('adstu', ['adust']),
#  ('acilooprs', ['acropolis']),
#  ('aabikn', ['abnaki']),
#  ('aaffimorrty', ['affirmatory']),
#  ('ac', ['ac']),
#  ('aceehinss', ['aeschines']),
#  ('aacdir', ['acarid']),
#  ('aceffgint', ['affecting']),
#  ('aacdeimnorsy', ['aerodynamics']),
#  ('aaccdeelnor', ['accelerando']),
#  ('abir', ['abri']),
#  ('adeeil', ['aedile']),
#  ('adderss', ['address']),
#  ('aabglor', ['aalborg']),
#  ('aacchiimortty', ['achromaticity']),
#  ('aablor', ['aboral']),
#  ('aaccceenpt', ['acceptance']),
#  ('aefforst', ['afforest']),
#  ('adeirsv', ['adviser']),
#  ('acceortu', ['accoutre', 'accouter']),
#  ('acdeeinoorst', ['aerodonetics']),
#  ('aeeinoorrssu', ['aeroneurosis']),
#  ('aadeiptv', ['adaptive']),
#  ('aachimmorst', ['achromatism']),
#  ('abdegimnrt', ['abridgment']),
#  ('aacdinootv', ['advocation']),
#  ('aacceinqttu', ['acquittance']),
#  ('aaadeirrsv', ['adversaria']),
#  ('aaadilx', ['adaxial']),
#  ('aacccdenor', ['accordance']),
#  ('aaadimny', ['adynamia']),
#  ('adenorstuuv', ['adventurous']),
#  ('aaduw', ['aduwa']),
#  ('acem', ['acme']),
#  ('acceeeelmorrt', ['accelerometer']),
#  ('aadeiiimnrsttv', ['administrative']),
#  ('aadflorw', ['aardwolf']),
#  ('acinsu', ['acinus']),
#  ('accept', ['accept']),
#  ('aaeffhrstt', ['aftershaft']),
#  ('acceemnorttu', ['accouterment']),
#  ('abbot', ['abbot']),
#  ('aeenosu', ['aeneous']),
#  ('aaadegnostuv', ['advantageous']),
#  ('addeeerss', ['addressee']),
#  ('aacclmortuu', ['accumulator']),
#  ('aegpstuy', ['aegyptus']),
#  ('aaacehn', ['achaean']),
#  ('aeehrt', ['aether']),
#  ('acddortu', ['adductor']),
#  ('aacinnootz', ['actinozoan']),
#  ('abhilos', ['abolish']),
#  ('abemnttu', ['abutment']),
#  ('aabet', ['abate']),
#  ('adeimnopt', ['ademption']),
#  ('aacehinoprtty', ['actinotherapy']),
#  ('aceilnor', ['acrolein']),
#  ('aaacdelm', ['aceldama']),
#  ('adejmnsttu', ['adjustment']),
#  ('adeeeimnrsttv', ['advertisement']),
#  ('abejru', ['abjure']),
#  ('aacinor', ['aaronic']),
#  ('aacclopu', ['acapulco']),
#  ('aacrsu', ['acarus']),
#  ('abilnotu', ['ablution', 'abutilon']),
#  ('aacceeelrt', ['accelerate']),
#  ('aaeefgimrt', ['afterimage']),
#  ('aeefrt', ['afreet']),
#  ('aabcort', ['acrobat']),
#  ('aabdddeeilnr', ['addlebrained']),
#  ('aaefhmrtt', ['aftermath']),
#  ('abelostu', ['absolute']),
#  ('acint', ['actin']),
#  ('acdeeenrtv', ['advertence']),
#  ('acciorst', ['acrostic']),
#  ('adddemnu', ['addendum']),
#  ('aabcdiinot', ['abdication']),
#  ('aabcciort', ['acrobatic']),
#  ('aaaaccehhlnnopt', ['acanthocephalan']),
#  ('aaceert', ['acerate']),
#  ('aaegmorr', ['aerogram']),
#  ('addeilsvy', ['advisedly']),
#  ('acddinotu', ['adduction']),
#  ('aceeefffrtt', ['aftereffect']),
#  ('aaccdimmnooot', ['accommodation']),
#  ('adeirstvy', ['adversity']),
#  ('add', ['add']),
#  ('aabbeeirtv', ['abbreviate']),
#  ('adeinsttv', ['adventist']),
#  ('aeloors', ['aerosol']),
#  ('adgiijnno', ['adjoining']),
#  ('adjnoru', ['adjourn']),
#  ('acimnoosty', ['actomyosin']),
#  ('aefnnoort', ['afternoon']),
#  ('aaaccdeimnnoor', ['adenocarcinoma']),
#  ('acdeiimrty', ['acidimetry']),
#  ('aaeefinnorsstt', ['aftersensation']),
#  ('accdginor', ['according']),
#  ('ad', ['ad']),
#  ('addeino', ['adenoid']),
#  ('aekl', ['leak', 'lake']),
#  ('abeegiinoss', ['abiogenesis']),
#  ('aaceeoprs', ['aerospace']),
#  ('aceostu', ['acetous']),
#  ('aaaceghinnoprtty', ['acanthopterygian']),
#  ('aabeimnot', ['abominate']),
#  ('aeffiiintv', ['affinitive']),
#  ('acdelnooty', ['acotyledon']),
#  ('acffilt', ['afflict']),
#  ('aaceiltuz', ['actualize']),
#  ('aaccentu', ['acutance']),
#  ('adhimnos', ['admonish']),
#  ('aacilqttu', ['acquittal']),
#  ('aabijnortu', ['abjuration']),
#  ('abhiimnsst', ['absinthism']),
#  ('aaffiiilnot', ['affiliation']),
#  ('adeiinosttuv', ['adventitious']),
#  ('aadgio', ['adagio']),
#  ('afflux', ['afflux']),
#  ('aacenot', ['actaeon']),
#  ('adios', ['adios']),
#  ('aabcelt', ['actable']),
#  ('adeeissv', ['adessive']),
#  ('aceeffitv', ['affective']),
#  ('aaeghoprr', ['aerograph']),
#  ('abb', ['abb']),
#  ('aaceertv', ['acervate']),
#  ('aacefiiinort', ['aerification']),
#  ('abcdortu', ['abductor']),
#  ('aeirs', ['aesir']),
#  ('aabdemrtu', ['adumbrate']),
#  ('aabcrstt', ['abstract']),
#  ('aegoru', ['aerugo']),
#  ('adeenrttv', ['advertent']),
#  ('aaddiilnot', ['additional']),
#  ('aceffhi', ['affiche']),
#  ('accdinoor', ['accordion']),
#  ('adiimnoss', ['admission']),
#  ('aabbcenors', ['absorbance']),
#  ('aefghorrttw', ['aftergrowth']),
#  ('acceoprt', ['acceptor']),
#  ('aadhiooprsu', ['adiaphorous']),
#  ('adeiinst', ['adenitis']),
#  ('ablotv', ['abvolt']),
#  ('aacgloory', ['acarology']),
#  ('abceegiinot', ['abiogenetic']),
#  ('acder', ['acred']),
#  ('acehlssuy', ['aeschylus']),
#  ('aabbcy', ['abbacy']),
#  ('aaaccilorstu', ['accusatorial']),
#  ('adentv', ['advent']),
#  ('aadffiitv', ['affidavit']),
#  ('abf', ['afb']),
#  ('abciiot', ['abiotic']),
#  ('aadrsstu', ['adrastus']),
#  ('aacfinr', ['african']),
#  ('aacdiirt', ['adriatic']),
#  ('aadelnsu', ['aalesund']),
#  ('aaceffirt', ['affricate']),
#  ('aadelnr', ['adrenal']),
#  ('abcdeiiort', ['aborticide']),
#  ('aachnostu', ['acanthous']),
#  ('aadhiimoprs', ['adiaphorism']),
#  ('abdeiilmss', ['admissible']),
#  ('abginttu', ['abutting']),
#  ('aaceffilnot', ['affectional']),
#  ('aacehimortz', ['achromatize']),
#  ('aabcdeit', ['abdicate']),
#  ('ablmoo', ['abloom']),
#  ('aaccdeilnt', ['accidental']),
#  ('adees', ['aedes']),
#  ('abdeo', ['abode', 'adobe']),
#  ('adiort', ['adroit']),
#  ('aabdlmru', ['adumbral']),
#  ('acceiiinprt', ['accipitrine']),
#  ('aaceglmory', ['acromegaly']),
#  ('adeelrrtu', ['adulterer']),
#  ('aaaru', ['aarau']),
#  ('aaabcehinrt', ['abranchiate']),
#  ('ademnnort', ['adornment']),
#  ('aadeltu', ['adulate']),
#  ('aacciinostu', ['acoustician']),
#  ('acdfiiy', ['acidify']),
#  ('aaeefrsttt', ['aftertaste']),
#  ('aegis', ['aegis']),
#  ('adffor', ['afford']),
#  ('acimmoss', ['acosmism']),
#  ('adz', ['adz']),
#  ('abeefnrrrtu', ['afterburner']),
#  ('aachmoorstu', ['achromatous']),
#  ('aaddeeil', ['adelaide']),
#  ('acort', ['actor']),
#  ('aabem', ['abeam']),
#  ('accesu', ['accuse']),
#  ('adehinos', ['adhesion']),
#  ('abinoort', ['abortion']),
#  ('aaacdeim', ['academia']),
#  ('abet', ['abet']),
#  ('acf', ['afc']),
#  ('abginnor', ['aborning']),
#  ('aeeffnrt', ['afferent']),
#  ('aacltu', ['actual']),
#  ('aabchor', ['abroach']),
#  ('acdi', ['acid']),
#  ('aaccr', ['accra']),
#  ('abmsy', ['abysm']),
#  ('aeemorrty', ['aerometry']),
#  ('abeeor', ['aerobe']),
#  ('aacdeem', ['academe']),
#  ('aaceffin', ['affiance']),
#  ('acdemoorr', ['acrodrome']),
#  ('abeeilmmoors', ['aeroembolism']),
#  ('acddit', ['addict']),
#  ('access', ['access']),
#  ('adeeemnorstuv', ['adventuresome']),
#  ('abde', ['abed']),
#  ('aablttu', ['abuttal']),
#  ('aaegimoopst', ['aegospotami']),
#  ('acehhilopt', ['achitophel']),
#  ('aaadinoptt', ['adaptation']),
#  ('abbdeors', ['absorbed']),
#  ('aaccdejny', ['adjacency']),
#  ('aabdeilmr', ['admirable']),
#  ('addeisv', ['advised']),
#  ('aeehoprty', ['aerophyte']),
#  ('aefir', ['afire']),
#  ('aaeegno', ['aegaeon']),
#  ('acchiimnooprt', ['actinomorphic']),
#  ('aacdefinrr', ['africander']),
#  ('aceehiimsstt', ['aestheticism']),
#  ('aaaaabbcdrr', ['abracadabra']),
#  ('aeeehoprrs', ['aerosphere']),
#  ('adeinorsuv', ['adenovirus']),
#  ('aaeeeghmoooprrrt', ['aerometeorograph']),
#  ('aabist', ['abatis']),
#  ('aceeffhinnprs', ['affenpinscher']),
#  ('aabenrrt', ['aberrant']),
#  ('abiioss', ['abiosis']),
#  ('acdeeiimrt', ['acidimeter']),
#  ('acdjntu', ['adjunct']),
#  ('aacccnnotuy', ['accountancy']),
#  ('abdnou', ['abound']),
#  ('aflou', ['afoul']),
#  ('aceenot', ['acetone']),
#  ('aabiimnnoot', ['abomination']),
#  ('aby', ['aby']),
#  ('abeeeimnsst', ['absenteeism']),
#  ('acdeelnost', ['adolescent']),
#  ('acceinort', ['accretion']),
#  ('adeeinn', ['adenine']),
#  ('abelosv', ['absolve']),
#  ('accdor', ['accord']),
#  ('aahrsu', ['aarhus']),
#  ('adeimnr', ['adermin']),
#  ('aabcdeery', ['abecedary']),
#  ('acemtu', ['acetum']),
#  ('acdhiilop', ['acidophil']),
#  ('aaeilot', ['aetolia']),
#  ('aadeimst', ['adamsite']),
#  ('aaabhmr', ['abraham']),
#  ('affiinty', ['affinity']),
#  ('aaccenptt', ['acceptant']),
#  ('aabenty', ['abeyant']),
#  ('acgint', ['acting']),
#  ('aadino', ['adonai']),
#  ('abellostuy', ['absolutely']),
#  ('adeeinnos', ['adenosine']),
#  ('acdddeit', ['addicted']),
#  ('abeefilr', ['afebrile']),
#  ('aacceilmtuuv', ['accumulative']),
#  ('accehiimnorstty', ['actinochemistry']),
#  ('aaabcdiit', ['adiabatic']),
#  ('accmostu', ['accustom']),
#  ('aceeemortt', ['acetometer']),
#  ('aaaccehnostu', ['acanthaceous']),
#  ('aadmn', ['adman']),
#  ('aabelz', ['ablaze']),
#  ('adelrtuy', ['adultery']),
#  ('abinoprtu', ['abruption']),
#  ('aabceert', ['acerbate']),
#  ('aaccilnorttuu', ['acculturation']),
#  ('acciimnnoty', ['actinomycin']),
#  ('aaaccilmnot', ['acclamation']),
#  ('abeisuv', ['abusive']),
#  ('aceffiiltv', ['afflictive']),
#  ('aceh', ['ache']),
#  ('aabck', ['aback']),
#  ('aacdeotv', ['advocate']),
#  ('aaabrsx', ['abraxas']),
#  ('aadr', ['adar']),
#  ('addiorty', ['additory']),
#  ('acdir', ['acrid']),
#  ('acdeiinr', ['acridine']),
#  ('aadeilnnr', ['adrenalin']),
#  ('aaffiimnort', ['affirmation']),
#  ('aaccelmtuu', ['accumulate'])]

# %% [markdown]
# Observe the results. Then, run filter:

# %%
filtered = grouped.filter(lambda x: len(x[1])>1)
filtered.collect()
# Out:
# [('abhmo', ['abohm', 'abmho']),
#  ('ace', ['aec', 'ace']),
#  ('abel', ['abel', 'able']),
#  ('deer', ['deer', 'reed']),
#  ('aabdor', ['aboard', 'abroad']),
#  ('elmno', ['lemon', 'melon']),
#  ('acceortu', ['accoutre', 'accouter']),
#  ('abilnotu', ['ablution', 'abutilon']),
#  ('aekl', ['leak', 'lake']),
#  ('abdeo', ['abode', 'adobe'])]

# %% [markdown]
# Then, let's run mapValues:

# %%
res1 = filtered.mapValues(lambda x: ", ".join(x))
res1.collect()
# Out:
# [('abhmo', 'abohm, abmho'),
#  ('ace', 'aec, ace'),
#  ('abel', 'abel, able'),
#  ('deer', 'deer, reed'),
#  ('aabdor', 'aboard, abroad'),
#  ('elmno', 'lemon, melon'),
#  ('acceortu', 'accoutre, accouter'),
#  ('abilnotu', 'ablution, abutilon'),
#  ('aekl', 'leak, lake'),
#  ('abdeo', 'abode, adobe')]

# %% [markdown]
# Finally, also apply mapValues to the unfiltered RDD and save both datasets on
# disk:

# %%
res2 = grouped.mapValues(lambda x: ", ".join(x))
res2.collect()
# Out:
# [('adeenory', 'aerodyne'),
#  ('aceehn', 'achene'),
#  ('abcesss', 'abscess'),
#  ('adnor', 'adorn'),
#  ('adfirt', 'adrift'),
#  ('aabdeorst', 'adsorbate'),
#  ('aceeimnqrtu', 'acquirement'),
#  ('acehnor', 'acheron'),
#  ('abhmo', 'abohm, abmho'),
#  ('aaagru', 'aargau'),
#  ('aacilttuy', 'actuality'),
#  ('aabcciorst', 'acrobatics'),
#  ('aacceinoptt', 'acceptation'),
#  ('aaffiln', 'affinal'),
#  ('adeein', 'aeneid'),
#  ('aciqtu', 'acquit'),
#  ('aaafiknrs', 'afrikaans'),
#  ('aabdnntu', 'abundant'),
#  ('abcdentu', 'abducent'),
#  ('acdnoort', 'acrodont'),
#  ('aceloty', 'acolyte'),
#  ('aaabbilt', 'abbatial'),
#  ('aaddms', 'addams'),
#  ('aeeimtt', 'teatime'),
#  ('adeersv', 'adverse'),
#  ('aadefr', 'afeard'),
#  ('aefghhortttu', 'afterthought'),
#  ('aaaceh', 'achaea'),
#  ('aabccelnotu', 'accountable'),
#  ('abceirty', 'acerbity'),
#  ('aaccooprrsu', 'acrocarpous'),
#  ('adjstu', 'adjust'),
#  ('accnotu', 'account'),
#  ('aacefiinrz', 'africanize'),
#  ('aacdeeilmor', 'aeromedical'),
#  ('ademstu', 'admetus'),
#  ('aaceimntu', 'acuminate'),
#  ('aa', 'aa'),
#  ('aaabcdeeinr', 'abecedarian'),
#  ('accdeint', 'accident'),
#  ('aaffiinotx', 'affixation'),
#  ('aaceiorstt', 'aerostatic'),
#  ('aabchioopr', 'acrophobia'),
#  ('aabcsu', 'abacus'),
#  ('aaegin', 'aegina'),
#  ('aacceiltu', 'aciculate'),
#  ('aacclru', 'accrual'),
#  ('aacilnr', 'acrilan'),
#  ('aacceelnrt', 'accelerant'),
#  ('aeehnoopr', 'aerophone'),
#  ('abehnry', 'abhenry'),
#  ('aabeemntt', 'abatement'),
#  ('aacdeeimt', 'acetamide'),
#  ('acemnu', 'acumen'),
#  ('abdegir', 'abridge'),
#  ('adeehisv', 'adhesive'),
#  ('aceeefiprt', 'afterpiece'),
#  ('acdiiiossttu', 'adscititious'),
#  ('adp', 'adp'),
#  ('aaafghinnst', 'afghanistan'),
#  ('aadeilnopr', 'adrianople'),
#  ('aaaccceiltt', 'acatalectic'),
#  ('abelnsty', 'absently'),
#  ('acehlosu', 'achelous'),
#  ('abcdins', 'abscind'),
#  ('aciittvy', 'activity'),
#  ('aaeiilrst', 'aerialist'),
#  ('acccdeiinooooprrrtt', 'adrenocorticotropic'),
#  ('acdeefkrt', 'afterdeck'),
#  ('aacdei', 'acedia'),
#  ('abiinoorstt', 'abortionist'),
#  ('aceeehimntv', 'achievement'),
#  ('adeiimnrst', 'administer'),
#  ('aacceenttu', 'accentuate'),
#  ('aaceloprt', 'acropetal'),
#  ('aaddx', 'addax'),
#  ('aegloory', 'aerology'),
#  ('aceinot', 'aconite'),
#  ('adder', 'adder'),
#  ('acdinoopt', 'actinopod'),
#  ('aaceehillstty', 'aesthetically'),
#  ('aeor', 'aero'),
#  ('aeno', 'aeon'),
#  ('aceilo', 'aeolic'),
#  ('aadfir', 'afraid'),
#  ('adimx', 'admix'),
#  ('aefmorstt', 'aftermost'),
#  ('aabinst', 'abstain'),
#  ('aceehisstt', 'aesthetics'),
#  ('aaaeghiopr', 'aerophagia'),
#  ('aefrt', 'after'),
#  ('aadilmrty', 'admiralty'),
#  ('acdeinotv', 'advection'),
#  ('aadeprt', 'adapter'),
#  ('aabhs', 'abash'),
#  ('acdeefft', 'affected'),
#  ('addeiitv', 'additive'),
#  ('accdeeelnos', 'adolescence'),
#  ('aceimu', 'aecium'),
#  ('aaddeghoprrss', 'addressograph'),
#  ('aeffoosttu', 'affettuoso'),
#  ('aadeg', 'adage'),
#  ('addinos', 'addison'),
#  ('affnort', 'affront'),
#  ('acdilosuu', 'acidulous'),
#  ('acdiinoprst', 'adscription'),
#  ('aciimnst', 'actinism'),
#  ('aabdelor', 'adorable'),
#  ('affinosu', 'affusion'),
#  ('aceitv', 'active'),
#  ('aacdejnt', 'adjacent'),
#  ('accilmuu', 'aciculum'),
#  ('aalot', 'aalto'),
#  ('aadinr', 'adrian'),
#  ('abiruzz', 'abruzzi'),
#  ('aaadeimnnt', 'adamantine'),
#  ('abimnorty', 'abnormity'),
#  ('abprtu', 'abrupt'),
#  ('aabbdeoorv', 'aboveboard'),
#  ('acdeeijtv', 'adjective'),
#  ('acceinoss', 'accession'),
#  ('aeops', 'aesop'),
#  ('aadeemrsu', 'admeasure'),
#  ('adltu', 'adult'),
#  ('aablmnor', 'abnormal'),
#  ('aeefimrtt', 'aftertime'),
#  ('aaeiinosttv', 'aestivation'),
#  ('aacchimort', 'achromatic'),
#  ('aaeffiimrtv', 'affirmative'),
#  ('abikru', 'abukir'),
#  ('aaciorttv', 'activator'),
#  ('aacdhinot', 'acanthoid'),
#  ('acdeeiopr', 'adipocere'),
#  ('abiilnoot', 'abolition'),
#  ('aacinqtu', 'acquaint'),
#  ('aaeilr', 'aerial'),
#  ('aadeeilnnr', 'adrenaline'),
#  ('acdeilntu', 'acidulent'),
#  ('accdii', 'acidic'),
#  ('aacdim', 'adamic'),
#  ('abenst', 'absent'),
#  ('abeov', 'above'),
#  ('aaccilu', 'acicula'),
#  ('accdgilnory', 'accordingly'),
#  ('acnot', 'acton'),
#  ('aceiloooprt', 'aeolotropic'),
#  ('abefginnrrtu', 'afterburning'),
#  ('aadjntuv', 'adjuvant'),
#  ('aabefinrrt', 'afterbrain'),
#  ('acllryy', 'acrylyl'),
#  ('acdeeilty', 'acetylide'),
#  ('aaacdotv', 'advocaat'),
#  ('aaccerssy', 'accessary'),
#  ('abeiioorss', 'aerobiosis'),
#  ('aabdeerr', 'aberdare'),
#  ('ace', 'aec, ace'),
#  ('aaeflm', 'aflame'),
#  ('affghirt', 'affright'),
#  ('abinooprst', 'absorption'),
#  ('aciisttv', 'activist'),
#  ('aacceiilmtz', 'acclimatize'),
#  ('abesu', 'abuse'),
#  ('aabelno', 'abalone'),
#  ('abdosy', 'abydos'),
#  ('aacoprsu', 'acarpous'),
#  ('aaadp', 'adapa'),
#  ('aacdeehimmnoorrsty', 'aerothermodynamics'),
#  ('aabeffl', 'affable'),
#  ('abersstu', 'abstruse'),
#  ('aceefflnu', 'affluence'),
#  ('aadinoort', 'adoration'),
#  ('acdijnnotu', 'adjunction'),
#  ('acdeeehnr', 'adherence'),
#  ('aceehiv', 'achieve'),
#  ('aacdeehimn', 'achaemenid'),
#  ('aegilooty', 'aetiology'),
#  ('aaceffinott', 'affectation'),
#  ('abdgiin', 'abiding'),
#  ('achilort', 'acrolith'),
#  ('accceilmop', 'accomplice'),
#  ('acimtu', 'actium'),
#  ('aaabdn', 'abadan'),
#  ('aaeinno', 'aeonian'),
#  ('aeeilort', 'aerolite'),
#  ('adeeefimnnoort', 'aforementioned'),
#  ('adeehnrt', 'adherent'),
#  ('aabcert', 'abreact'),
#  ('aabcenoprst', 'absorptance'),
#  ('acciostu', 'acoustic'),
#  ('abceiss', 'abscise'),
#  ('abel', 'abel, able'),
#  ('aabiinrrtt', 'abirritant'),
#  ('aaceeehioprrsttu', 'aerotherapeutics'),
#  ('aabdelr', 'abelard'),
#  ('1a', 'a1'),
#  ('aaciimnnortuu', 'actinouranium'),
#  ('abcer', 'acerb'),
#  ('aceeiooprs', 'aeciospore'),
#  ('aabdijn', 'abidjan'),
#  ('aaceffhinrs', 'affranchise'),
#  ('acdeegklnow', 'acknowledge'),
#  ('aaaceilnpsu', 'aesculapian'),
#  ('abeeiln', 'abilene'),
#  ('adeeisv', 'advisee'),
#  ('aablmos', 'absalom'),
#  ('accdeii', 'accidie'),
#  ('aaccdeimmootv', 'accommodative'),
#  ('abotu', 'about'),
#  ('adeimr', 'admire'),
#  ('aam', 'aam'),
#  ('adeioptv', 'adoptive'),
#  ('acegnor', 'acrogen'),
#  ('aabcceelpt', 'acceptable'),
#  ('aaeorrt', 'aerator'),
#  ('aabcefiinortt', 'abortifacient'),
#  ('aabeegnt', 'abnegate'),
#  ('aabbeiinortv', 'abbreviation'),
#  ('aeeffilrt', 'afterlife'),
#  ('aaceeltty', 'acetylate'),
#  ('aaegortt', 'aegrotat'),
#  ('addden', 'addend'),
#  ('acceeiqsu', 'acquiesce'),
#  ('aaabilx', 'abaxial'),
#  ('aadghinrt', 'adigranth'),
#  ('abddeeimnnst', 'absentminded'),
#  ('aaderrsvy', 'adversary'),
#  ('abeeissv', 'abessive'),
#  ('aabilou', 'aboulia'),
#  ('aabceilnot', 'actionable'),
#  ('adeor', 'adore'),
#  ('aacetu', 'acuate'),
#  ('aabnnost', 'absonant'),
#  ('acccehoruu', 'accoucheur'),
#  ('aaccfiimnor', 'acinaciform'),
#  ('affimr', 'affirm'),
#  ('abdei', 'abide'),
#  ('adeenrrtuv', 'adventurer'),
#  ('aachmort', 'achromat'),
#  ('aaccmnopy', 'accompany'),
#  ('aaccdovy', 'advocacy'),
#  ('acelsuu', 'aculeus'),
#  ('aaeeisttv', 'aestivate'),
#  ('aacfiinrst', 'africanist'),
#  ('aadmss', 'admass'),
#  ('adit', 'adit'),
#  ('adeeilnrtu', 'adulterine'),
#  ('aacdior', 'acaroid'),
#  ('accenprtuuu', 'acupuncture'),
#  ('aaccimnopsty', 'accompanyist'),
#  ('aceffinot', 'affection'),
#  ('abbors', 'absorb'),
#  ('aaccdgimmnoot', 'accommodating'),
#  ('aeegsu', 'aegeus'),
#  ('aaeens', 'aeneas'),
#  ('acciimnoossty', 'actinomycosis'),
#  ('aacclsu', 'accusal'),
#  ('aabcinorstt', 'abstraction'),
#  ('aaabdelpt', 'adaptable'),
#  ('aden', 'aden'),
#  ('adeiu', 'adieu'),
#  ('aaccdeiir', 'acaricide'),
#  ('aery', 'aery'),
#  ('adeeirstv', 'advertise'),
#  ('acceiiprt', 'accipiter'),
#  ('acis', 'acis'),
#  ('aadefrrstw', 'afterwards'),
#  ('aadeiimnrstt', 'administrate'),
#  ('acgilnooty', 'actinology'),
#  ('adeisv', 'advise'),
#  ('aademno', 'adenoma'),
#  ('acddeu', 'adduce'),
#  ('acdiioss', 'acidosis'),
#  ('acht', 'acth'),
#  ('aacdhhilorry', 'achlorhydria'),
#  ('accceehmnotu', 'accouchement'),
#  ('aab', 'aba'),
#  ('aabciimnorsstt', 'abstractionism'),
#  ('aaeilno', 'aeolian'),
#  ('aaeorstt', 'aerostat'),
#  ('abdenorst', 'adsorbent'),
#  ('accdemostu', 'accustomed'),
#  ('acceeinqstu', 'acquiescent'),
#  ('act', 'act'),
#  ('aabekotu', 'abeokuta'),
#  ('abbess', 'abbess'),
#  ('accenort', 'accentor'),
#  ('aachimnort', 'achromatin'),
#  ('aabiortt', 'abattoir'),
#  ('aacccruy', 'accuracy'),
#  ('acddeeimnooty', 'adenoidectomy'),
#  ('aceeimnortt', 'actinometer'),
#  ('aaffry', 'affray'),
#  ('aaceflprt', 'afterclap'),
#  ('abceehnorr', 'abhorrence'),
#  ('aceeooprs', 'aeroscope'),
#  ('aabceiillorsst', 'aeroballistics'),
#  ('acceehillnoty', 'acetylcholine'),
#  ('aefhrs', 'afresh'),
#  ('aadeiinttv', 'adventitia'),
#  ('aaddeilno', 'adenoidal'),
#  ('aaadkrrv', 'aardvark'),
#  ('aaccdnort', 'accordant'),
#  ('aabilu', 'abulia'),
#  ('adimnoorty', 'admonitory'),
#  ('acituy', 'acuity'),
#  ('aablssy', 'abyssal'),
#  ('af', 'af'),
#  ('aaceett', 'acetate'),
#  ('aadm', 'adam'),
#  ('aaadmnt', 'adamant'),
#  ('addeilmtty', 'admittedly'),
#  ('aciimntu', 'actinium'),
#  ('aaccd', 'accad'),
#  ('abcceeilss', 'accessible'),
#  ('abeinnostt', 'abstention'),
#  ('aaent', 'aetna'),
#  ('aaccdeim', 'academic'),
#  ('aaeert', 'aerate'),
#  ('acdeemnoty', 'adenectomy'),
#  ('aeeir', 'aerie'),
#  ('aabgiilnor', 'aboriginal'),
#  ('aacddiijnotu', 'adjudication'),
#  ('abdegnooruv', 'aboveground'),
#  ('admtuy', 'adytum'),
#  ('abdirstuy', 'absurdity'),
#  ('aabgiil', 'abigail'),
#  ('addiinot', 'addition'),
#  ('aeflrttu', 'aflutter'),
#  ('aeeimrt', 'meatier'),
#  ('abbenorst', 'absorbent'),
#  ('acceeprt', 'accepter'),
#  ('aabcist', 'abacist'),
#  ('acceit', 'acetic'),
#  ('acen', 'acne'),
#  ('adeenrsstuv', 'adventuress'),
#  ('acly', 'acyl'),
#  ('acdeiv', 'advice'),
#  ('accost', 'accost'),
#  ('aciimstv', 'activism'),
#  ('acefft', 'affect'),
#  ('abhor', 'abhor'),
#  ('aaeghoprry', 'aerography'),
#  ('aacddenv', 'advanced'),
#  ('abcdinotu', 'abduction'),
#  ('abdginno', 'abingdon'),
#  ('aadiimnorrstt', 'administrator'),
#  ('aanor', 'aaron'),
#  ('aceiqru', 'acquire'),
#  ('abegiinor', 'aborigine'),
#  ('aaceffiirtv', 'affricative'),
#  ('abdors', 'adsorb'),
#  ('aacdeijltv', 'adjectival'),
#  ('aacceehimnor', 'aeromechanic'),
#  ('aaeffir', 'affaire'),
#  ('aceinoorrt', 'acroterion'),
#  ('aabes', 'abase'),
#  ('aabeiirrtt', 'abirritate'),
#  ('aaccelrttuu', 'acculturate'),
#  ('aadjnttu', 'adjutant'),
#  ('aacdfiinoo', 'aficionado'),
#  ('abcceir', 'acerbic'),
#  ('adnoosvw', 'advowson'),
#  ('acciint', 'actinic'),
#  ('aabbeilmno', 'abominable'),
#  ('aabeilps', 'ablepsia'),
#  ('aabeinorrt', 'aberration'),
#  ('acdeno', 'acnode'),
#  ('abtu', 'abut'),
#  ('ab', 'ab'),
#  ('acetu', 'acute'),
#  ('aaacceinnqtu', 'acquaintance'),
#  ('aacdeemnntv', 'advancement'),
#  ('adopt', 'adopt'),
#  ('abdhiit', 'adhibit'),
#  ('aaeeimnorr', 'aeromarine'),
#  ('acdeegklmnnotw', 'acknowledgment'),
#  ('addeopt', 'adopted'),
#  ('aacdequy', 'adequacy'),
#  ('aacehlopsu', 'acephalous'),
#  ('acciosstu', 'acoustics'),
#  ('aaacdhilnooprs', 'achondroplasia'),
#  ('acffiilnot', 'affliction'),
#  ('adelr', 'adler'),
#  ('aabeirsv', 'abrasive'),
#  ('aaccertu', 'accurate'),
#  ('afirt', 'afrit'),
#  ('adeelrsstu', 'adulteress'),
#  ('abccemntu', 'accumbent'),
#  ('adimt', 'admit'),
#  ('aceiiiqstuv', 'acquisitive'),
#  ('aacceelnstu', 'acaulescent'),
#  ('acinnot', 'actinon'),
#  ('aadms', 'adams'),
#  ('abcdtu', 'abduct'),
#  ('aaadilru', 'adularia'),
#  ('aabcisss', 'abscissa'),
#  ('adez', 'adze'),
#  ('abilnoostu', 'absolution'),
#  ('aaabelqsttuu', 'absquatulate'),
#  ('adelorstuu', 'adulterous'),
#  ('acehills', 'achilles'),
#  ('aabb', 'abba'),
#  ('aaabc', 'abaca'),
#  ('acceenst', 'acescent'),
#  ('abc', 'abc'),
#  ('aacehst', 'achates'),
#  ('aabegort', 'abrogate'),
#  ('adeimrtux', 'admixture'),
#  ('ado', 'ado'),
#  ('acmnory', 'acronym'),
#  ('aceeors', 'acerose'),
#  ('adeiimssv', 'admissive'),
#  ('aacrtuy', 'actuary'),
#  ('aadefrrtw', 'afterward'),
#  ('aaffirs', 'affairs'),
#  ('acinot', 'action'),
#  ('aacdeimntt', 'admittance'),
#  ('accent', 'accent'),
#  ('acceilrtuuz', 'acculturize'),
#  ('aaccelntu', 'accentual'),
#  ('aafflstu', 'afflatus'),
#  ('adeehr', 'adhere'),
#  ('aabinors', 'abrasion'),
#  ('aaccdelo', 'accolade'),
#  ('abdemno', 'abdomen'),
#  ('aaeilstv', 'aestival'),
#  ('abssy', 'abyss'),
#  ('abeegnrstt', 'abstergent'),
#  ('acdeiilmn', 'adminicle'),
#  ('aafghn', 'afghan'),
#  ('acefhkorst', 'aftershock'),
#  ('aacfir', 'africa'),
#  ('aabdeilrv', 'adverbial'),
#  ('aabehioopr', 'aerophobia'),
#  ('aacdeiltu', 'acidulate'),
#  ('aaccilmnotuu', 'accumulation'),
#  ('acddiinot', 'addiction'),
#  ('aefnnoorst', 'afternoons'),
#  ('aceioprrs', 'acrospire'),
#  ('aeefimort', 'aforetime'),
#  ('abceens', 'absence'),
#  ('aaacci', 'acacia'),
#  ('abbi', 'abib'),
#  ('aelosu', 'aeolus'),
#  ('aadeeirstvv', 'adversative'),
#  ('aefimorr', 'aeriform'),
#  ('aacceehimnors', 'aeromechanics'),
#  ('aaiil', 'aalii'),
#  ('aadeenru', 'adenauer'),
#  ('aaccorstuy', 'accusatory'),
#  ('aacddeeehlty', 'acetaldehyde'),
#  ('aaccimnopst', 'accompanist'),
#  ('aabiinssy', 'abyssinia'),
#  ('aaeffiilt', 'affiliate'),
#  ('aefor', 'afore'),
#  ('aciiinoqstu', 'acquisition'),
#  ('aabcelmtuu', 'acetabulum'),
#  ('abceeinnst', 'abstinence'),
#  ('accdersu', 'accursed'),
#  ('aadow', 'adowa'),
#  ('abdeegno', 'abednego'),
#  ('ably', 'ably'),
#  ('abcdeu', 'abduce'),
#  ('abbclmoou', 'abcoulomb'),
#  ('aaabdnrt', 'abradant'),
#  ('aabceiorst', 'aerobatics'),
#  ('acersst', 'actress'),
#  ('abbey', 'abbey'),
#  ('abort', 'abort'),
#  ('abciinorstt', 'abstriction'),
#  ('aacceistuv', 'accusative'),
#  ('acdiity', 'acidity'),
#  ('aceehistt', 'aesthetic'),
#  ('accilry', 'acrylic'),
#  ('adegiinrstv', 'advertising'),
#  ('aaacdi', 'acadia'),
#  ('abdrsu', 'absurd'),
#  ('aafr', 'afar'),
#  ('aabbceefinorst', 'absorbefacient'),
#  ('accehilmmnopst', 'accomplishment'),
#  ('aaaaccccirtu', 'acciaccatura'),
#  ('acnor', 'acorn'),
#  ('aabeempr', 'abampere'),
#  ('aablsttu', 'abuttals'),
#  ('adept', 'adept'),
#  ('aacettu', 'actuate'),
#  ('aabilnot', 'ablation'),
#  ('aaccilru', 'acicular'),
#  ('aadent', 'adnate'),
#  ('aafghin', 'afghani'),
#  ('abciinosss', 'abscission'),
#  ('abehnorrt', 'abhorrent'),
#  ('aaceegr', 'acreage'),
#  ('aabeiltv', 'ablative'),
#  ('acceeimnotty', 'actinomycete'),
#  ('adeforrtw', 'afterword'),
#  ('acer', 'acre'),
#  ('aabceinort', 'abreaction'),
#  ('acccily', 'acyclic'),
#  ('acdiinot', 'actinoid'),
#  ('aciimnoorsu', 'acrimonious'),
#  ('aaaciirss', 'acariasis'),
#  ('aaclltuy', 'actually'),
#  ('aabmmosu', 'abomasum'),
#  ('acceinrt', 'acentric'),
#  ('abeeenst', 'absentee'),
#  ('aaeefhrtt', 'afterheat'),
#  ('aabbdeeirtv', 'abbreviated'),
#  ('aft', 'aft'),
#  ('aacceelorrt', 'accelerator'),
#  ('afoot', 'afoot'),
#  ('aaeegn', 'aegean'),
#  ('acimnory', 'acrimony'),
#  ('aeeiillop', 'aeolipile'),
#  ('aaceeffinott', 'affectionate'),
#  ('aefghhoorttu', 'aforethought'),
#  ('aadeelrttu', 'adulterate'),
#  ('adnow', 'adown'),
#  ('abeel', 'abele'),
#  ('aaeinoorstt', 'aerostation'),
#  ('afor', 'afro'),
#  ('aacceimmnnopt', 'accompaniment'),
#  ('adeflorrtw', 'afterworld'),
#  ('aabelt', 'ablate'),
#  ('abcdnos', 'abscond'),
#  ('aaceiorsstt', 'aerostatics'),
#  ('aeghisstu', 'aegisthus'),
#  ('acelty', 'acetyl'),
#  ('aacdeinqtu', 'acquainted'),
#  ('aabcderstt', 'abstracted'),
#  ('abceior', 'aerobic'),
#  ('abbeorrs', 'absorber'),
#  ('acimnoor', 'acromion'),
#  ('aaefiknrr', 'afrikaner'),
#  ('acddeiitv', 'addictive'),
#  ('aacceinnottu', 'accentuation'),
#  ('a', 'a'),
#  ('accceenrst', 'accrescent'),
#  ('addegju', 'adjudge'),
#  ('aadeilnorttu', 'adulteration'),
#  ('aabddenno', 'abandoned'),
#  ('deer', 'deer, reed'),
#  ('aaccdeiimms', 'academicism'),
#  ('aaffint', 'affiant'),
#  ('aadeeemmnrstu', 'admeasurement'),
#  ('aaccchor', 'accroach'),
#  ('aaberst', 'abreast'),
#  ('acceru', 'accrue'),
#  ('accdeirt', 'accredit'),
#  ('adeeimnstv', 'advisement'),
#  ('aadddeelpt', 'addlepated'),
#  ('aegir', 'aegir'),
#  ('acfiimnort', 'actiniform'),
#  ('aacdehlmosuy', 'achlamydeous'),
#  ('aadegiott', 'adagietto'),
#  ('acceert', 'accrete'),
#  ('aabft', 'abaft'),
#  ('aefiry', 'aerify'),
#  ('adejru', 'adjure'),
#  ('aaceeltu', 'aculeate'),
#  ('adijnot', 'adjoint'),
#  ('aacdilntu', 'acidulant'),
#  ('aadefiknrr', 'afrikander'),
#  ('abilmosstu', 'absolutism'),
#  ('aabbeiillnv', 'abbevillian'),
#  ('aeilos', 'aeolis'),
#  ('abuzz', 'abuzz'),
#  ('aaenortu', 'aeronaut'),
#  ('aadiimnort', 'admiration'),
#  ('aabmp', 'abamp'),
#  ('adejmnnortu', 'adjournment'),
#  ('acdeeehiinnoptt', 'acetophenetidin'),
#  ('aadefgrrtu', 'afterguard'),
#  ('adeiops', 'adipose'),
#  ('acefity', 'acetify'),
#  ('abdeeenr', 'aberdeen'),
#  ('aaaccdeiimn', 'academician'),
#  ('adeffin', 'affined'),
#  ('aabceeny', 'abeyance'),
#  ('adiimnnoot', 'admonition'),
#  ('abderv', 'adverb'),
#  ('aabttw', 'abwatt'),
#  ('aadiiimnnorstt', 'administration'),
#  ('aaflot', 'afloat'),
#  ('addhlootu', 'adulthood'),
#  ('aaabdfr', 'abfarad'),
#  ('abiioprsttvy', 'absorptivity'),
#  ('abeklmos', 'abelmosk'),
#  ('adijno', 'adjoin'),
#  ('aabdis', 'abdias'),
#  ('accdehilmops', 'accomplished'),
#  ('abdeforty', 'afterbody'),
#  ('abeils', 'abseil'),
#  ('adeimnrstuv', 'adventurism'),
#  ('aaccdemmoot', 'accommodate'),
#  ('aadefiors', 'aforesaid'),
#  ('aacdeffin', 'affianced'),
#  ('aabcdennu', 'abundance'),
#  ('aadeeqtu', 'adequate'),
#  ('aberttu', 'abutter'),
#  ('aaeeoprsu', 'aeropause'),
#  ('aacehn', 'aachen'),
#  ('aacilnt', 'actinal'),
#  ('aeeehstt', 'aesthete'),
#  ('aadilnotu', 'adulation'),
#  ('aabltu', 'ablaut'),
#  ('accdesu', 'accused'),
#  ('adeemoorr', 'aerodrome'),
#  ('acddtu', 'adduct'),
#  ('aachnstu', 'acanthus'),
#  ('affix', 'affix'),
#  ('aaacdlu', 'acaudal'),
#  ('abiilty', 'ability'),
#  ('aaacdin', 'acadian'),
#  ('adinos', 'adonis'),
#  ('acfiimnor', 'aciniform'),
#  ('aceorrt', 'acroter'),
#  ('aadeinoort', 'aerodontia'),
#  ('aaadegntv', 'advantage'),
#  ('aaeehisst', 'aesthesia'),
#  ('aeffin', 'affine'),
#  ('aablmsy', 'abysmal'),
#  ('aabdnno', 'abandon'),
#  ('aadelnrttu', 'adulterant'),
#  ('aabbdis', 'abbasid'),
#  ('abegilooory', 'aerobiology'),
#  ('aabilmnorty', 'abnormality'),
#  ('aaceilpssuu', 'aesculapius'),
#  ('aceiilnott', 'actinolite'),
#  ('aaccnnottu', 'accountant'),
#  ('acceelmnoptu', 'accouplement'),
#  ('accdeept', 'accepted'),
#  ('addginnot', 'addington'),
#  ('aaeelnopr', 'aeroplane'),
#  ('acchimor', 'achromic'),
#  ('aabdeilsv', 'advisable'),
#  ('abeiortv', 'abortive'),
#  ('aacelt', 'acetal'),
#  ('adiorsvy', 'advisory'),
#  ('acdehinort', 'achondrite'),
#  ('aaceittv', 'activate'),
#  ('aabdor', 'aboard, abroad'),
#  ('aacddeijtu', 'adjudicate'),
#  ('abcejt', 'abject'),
#  ('aaceefrrt', 'aftercare'),
#  ('aacdemy', 'academy'),
#  ('aacemnory', 'aeromancy'),
#  ('aaccilm', 'acclaim'),
#  ('aacdlostuy', 'adactylous'),
#  ('adefil', 'afield'),
#  ('abeimosstu', 'abstemious'),
#  ('aacceilmt', 'acclimate'),
#  ('acceorssy', 'accessory'),
#  ('abbginors', 'absorbing'),
#  ('aaciint', 'actinia'),
#  ('addel', 'addle'),
#  ('aaffir', 'affair'),
#  ('aabciinorssttt', 'abstractionist'),
#  ('aefglortw', 'afterglow'),
#  ('aabder', 'abrade'),
#  ('aadeimt', 'adamite'),
#  ('accginnotu', 'accounting'),
#  ('aaceinorstu', 'aeronautics'),
#  ('acchilmops', 'accomplish'),
#  ('aabddno', 'abaddon'),
#  ('acciiltvy', 'acclivity'),
#  ('acdino', 'adonic'),
#  ('accceeeinqsu', 'acquiescence'),
#  ('aaaccgnou', 'aconcagua'),
#  ('aacehnrr', 'achernar'),
#  ('eeimrtt', 'termite'),
#  ('abehinst', 'absinthe'),
#  ('aabdilmno', 'abdominal'),
#  ('aaadn', 'adana'),
#  ('aceiillnorrty', 'acrylonitrile'),
#  ('aaacdehimnrty', 'adiathermancy'),
#  ('aacdeeiilnt', 'acetanilide'),
#  ('aceeelnty', 'acetylene'),
#  ('abeortt', 'abettor'),
#  ('aacceeilnort', 'acceleration'),
#  ('aeeemorrt', 'aerometer'),
#  ('abefhirrtt', 'afterbirth'),
#  ('abdimnoosu', 'abdominous'),
#  ('aacehlp', 'acaleph'),
#  ('abm', 'abm'),
#  ('aabcdeeimru', 'abecedarium'),
#  ('aadpt', 'adapt'),
#  ('aadilmr', 'admiral'),
#  ('aaceeirt', 'acierate'),
#  ('acorss', 'across'),
#  ('acccdeein', 'accidence'),
#  ('adertv', 'advert'),
#  ('adegi', 'adige'),
#  ('accdee', 'accede'),
#  ('aadefmprt', 'afterdamp'),
#  ('aacefiilnrv', 'acriflavine'),
#  ('aaddeimntt', 'additament'),
#  ('aaccinostu', 'accusation'),
#  ('elmno', 'lemon, melon'),
#  ('aefflntu', 'affluent'),
#  ('aacdenv', 'advance'),
#  ('adeenrtuv', 'adventure'),
#  ('aalst', 'aalst'),
#  ('adstu', 'adust'),
#  ('acilooprs', 'acropolis'),
#  ('aabikn', 'abnaki'),
#  ('aaffimorrty', 'affirmatory'),
#  ('ac', 'ac'),
#  ('aceehinss', 'aeschines'),
#  ('aacdir', 'acarid'),
#  ('aceffgint', 'affecting'),
#  ('aacdeimnorsy', 'aerodynamics'),
#  ('aaccdeelnor', 'accelerando'),
#  ('abir', 'abri'),
#  ('adeeil', 'aedile'),
#  ('adderss', 'address'),
#  ('aabglor', 'aalborg'),
#  ('aacchiimortty', 'achromaticity'),
#  ('aablor', 'aboral'),
#  ('aaccceenpt', 'acceptance'),
#  ('aefforst', 'afforest'),
#  ('adeirsv', 'adviser'),
#  ('acceortu', 'accoutre, accouter'),
#  ('acdeeinoorst', 'aerodonetics'),
#  ('aeeinoorrssu', 'aeroneurosis'),
#  ('aadeiptv', 'adaptive'),
#  ('aachimmorst', 'achromatism'),
#  ('abdegimnrt', 'abridgment'),
#  ('aacdinootv', 'advocation'),
#  ('aacceinqttu', 'acquittance'),
#  ('aaadeirrsv', 'adversaria'),
#  ('aaadilx', 'adaxial'),
#  ('aacccdenor', 'accordance'),
#  ('aaadimny', 'adynamia'),
#  ('adenorstuuv', 'adventurous'),
#  ('aaduw', 'aduwa'),
#  ('acem', 'acme'),
#  ('acceeeelmorrt', 'accelerometer'),
#  ('aadeiiimnrsttv', 'administrative'),
#  ('aadflorw', 'aardwolf'),
#  ('acinsu', 'acinus'),
#  ('accept', 'accept'),
#  ('aaeffhrstt', 'aftershaft'),
#  ('acceemnorttu', 'accouterment'),
#  ('abbot', 'abbot'),
#  ('aeenosu', 'aeneous'),
#  ('aaadegnostuv', 'advantageous'),
#  ('addeeerss', 'addressee'),
#  ('aacclmortuu', 'accumulator'),
#  ('aegpstuy', 'aegyptus'),
#  ('aaacehn', 'achaean'),
#  ('aeehrt', 'aether'),
#  ('acddortu', 'adductor'),
#  ('aacinnootz', 'actinozoan'),
#  ('abhilos', 'abolish'),
#  ('abemnttu', 'abutment'),
#  ('aabet', 'abate'),
#  ('adeimnopt', 'ademption'),
#  ('aacehinoprtty', 'actinotherapy'),
#  ('aceilnor', 'acrolein'),
#  ('aaacdelm', 'aceldama'),
#  ('adejmnsttu', 'adjustment'),
#  ('adeeeimnrsttv', 'advertisement'),
#  ('abejru', 'abjure'),
#  ('aacinor', 'aaronic'),
#  ('aacclopu', 'acapulco'),
#  ('aacrsu', 'acarus'),
#  ('abilnotu', 'ablution, abutilon'),
#  ('aacceeelrt', 'accelerate'),
#  ('aaeefgimrt', 'afterimage'),
#  ('aeefrt', 'afreet'),
#  ('aabcort', 'acrobat'),
#  ('aabdddeeilnr', 'addlebrained'),
#  ('aaefhmrtt', 'aftermath'),
#  ('abelostu', 'absolute'),
#  ('acint', 'actin'),
#  ('acdeeenrtv', 'advertence'),
#  ('acciorst', 'acrostic'),
#  ('adddemnu', 'addendum'),
#  ('aabcdiinot', 'abdication'),
#  ('aabcciort', 'acrobatic'),
#  ('aaaaccehhlnnopt', 'acanthocephalan'),
#  ('aaceert', 'acerate'),
#  ('aaegmorr', 'aerogram'),
#  ('addeilsvy', 'advisedly'),
#  ('acddinotu', 'adduction'),
#  ('aceeefffrtt', 'aftereffect'),
#  ('aaccdimmnooot', 'accommodation'),
#  ('adeirstvy', 'adversity'),
#  ('add', 'add'),
#  ('aabbeeirtv', 'abbreviate'),
#  ('adeinsttv', 'adventist'),
#  ('aeloors', 'aerosol'),
#  ('adgiijnno', 'adjoining'),
#  ('adjnoru', 'adjourn'),
#  ('acimnoosty', 'actomyosin'),
#  ('aefnnoort', 'afternoon'),
#  ('aaaccdeimnnoor', 'adenocarcinoma'),
#  ('acdeiimrty', 'acidimetry'),
#  ('aaeefinnorsstt', 'aftersensation'),
#  ('accdginor', 'according'),
#  ('ad', 'ad'),
#  ('addeino', 'adenoid'),
#  ('aekl', 'leak, lake'),
#  ('abeegiinoss', 'abiogenesis'),
#  ('aaceeoprs', 'aerospace'),
#  ('aceostu', 'acetous'),
#  ('aaaceghinnoprtty', 'acanthopterygian'),
#  ('aabeimnot', 'abominate'),
#  ('aeffiiintv', 'affinitive'),
#  ('acdelnooty', 'acotyledon'),
#  ('acffilt', 'afflict'),
#  ('aaceiltuz', 'actualize'),
#  ('aaccentu', 'acutance'),
#  ('adhimnos', 'admonish'),
#  ('aacilqttu', 'acquittal'),
#  ('aabijnortu', 'abjuration'),
#  ('abhiimnsst', 'absinthism'),
#  ('aaffiiilnot', 'affiliation'),
#  ('adeiinosttuv', 'adventitious'),
#  ('aadgio', 'adagio'),
#  ('afflux', 'afflux'),
#  ('aacenot', 'actaeon'),
#  ('adios', 'adios'),
#  ('aabcelt', 'actable'),
#  ('adeeissv', 'adessive'),
#  ('aceeffitv', 'affective'),
#  ('aaeghoprr', 'aerograph'),
#  ('abb', 'abb'),
#  ('aaceertv', 'acervate'),
#  ('aacefiiinort', 'aerification'),
#  ('abcdortu', 'abductor'),
#  ('aeirs', 'aesir'),
#  ('aabdemrtu', 'adumbrate'),
#  ('aabcrstt', 'abstract'),
#  ('aegoru', 'aerugo'),
#  ('adeenrttv', 'advertent'),
#  ('aaddiilnot', 'additional'),
#  ('aceffhi', 'affiche'),
#  ('accdinoor', 'accordion'),
#  ('adiimnoss', 'admission'),
#  ('aabbcenors', 'absorbance'),
#  ('aefghorrttw', 'aftergrowth'),
#  ('acceoprt', 'acceptor'),
#  ('aadhiooprsu', 'adiaphorous'),
#  ('adeiinst', 'adenitis'),
#  ('ablotv', 'abvolt'),
#  ('aacgloory', 'acarology'),
#  ('abceegiinot', 'abiogenetic'),
#  ('acder', 'acred'),
#  ('acehlssuy', 'aeschylus'),
#  ('aabbcy', 'abbacy'),
#  ('aaaccilorstu', 'accusatorial'),
#  ('adentv', 'advent'),
#  ('aadffiitv', 'affidavit'),
#  ('abf', 'afb'),
#  ('abciiot', 'abiotic'),
#  ('aadrsstu', 'adrastus'),
#  ('aacfinr', 'african'),
#  ('aacdiirt', 'adriatic'),
#  ('aadelnsu', 'aalesund'),
#  ('aaceffirt', 'affricate'),
#  ('aadelnr', 'adrenal'),
#  ('abcdeiiort', 'aborticide'),
#  ('aachnostu', 'acanthous'),
#  ('aadhiimoprs', 'adiaphorism'),
#  ('abdeiilmss', 'admissible'),
#  ('abginttu', 'abutting'),
#  ('aaceffilnot', 'affectional'),
#  ('aacehimortz', 'achromatize'),
#  ('aabcdeit', 'abdicate'),
#  ('ablmoo', 'abloom'),
#  ('aaccdeilnt', 'accidental'),
#  ('adees', 'aedes'),
#  ('abdeo', 'abode, adobe'),
#  ('adiort', 'adroit'),
#  ('aabdlmru', 'adumbral'),
#  ('acceiiinprt', 'accipitrine'),
#  ('aaceglmory', 'acromegaly'),
#  ('adeelrrtu', 'adulterer'),
#  ('aaaru', 'aarau'),
#  ('aaabcehinrt', 'abranchiate'),
#  ('ademnnort', 'adornment'),
#  ('aadeltu', 'adulate'),
#  ('aacciinostu', 'acoustician'),
#  ('acdfiiy', 'acidify'),
#  ('aaeefrsttt', 'aftertaste'),
#  ('aegis', 'aegis'),
#  ('adffor', 'afford'),
#  ('acimmoss', 'acosmism'),
#  ('adz', 'adz'),
#  ('abeefnrrrtu', 'afterburner'),
#  ('aachmoorstu', 'achromatous'),
#  ('aaddeeil', 'adelaide'),
#  ('acort', 'actor'),
#  ('aabem', 'abeam'),
#  ('accesu', 'accuse'),
#  ('adehinos', 'adhesion'),
#  ('abinoort', 'abortion'),
#  ('aaacdeim', 'academia'),
#  ('abet', 'abet'),
#  ('acf', 'afc'),
#  ('abginnor', 'aborning'),
#  ('aeeffnrt', 'afferent'),
#  ('aacltu', 'actual'),
#  ('aabchor', 'abroach'),
#  ('acdi', 'acid'),
#  ('aaccr', 'accra'),
#  ('abmsy', 'abysm'),
#  ('aeemorrty', 'aerometry'),
#  ('abeeor', 'aerobe'),
#  ('aacdeem', 'academe'),
#  ('aaceffin', 'affiance'),
#  ('acdemoorr', 'acrodrome'),
#  ('abeeilmmoors', 'aeroembolism'),
#  ('acddit', 'addict'),
#  ('access', 'access'),
#  ('adeeemnorstuv', 'adventuresome'),
#  ('abde', 'abed'),
#  ('aablttu', 'abuttal'),
#  ('aaegimoopst', 'aegospotami'),
#  ('acehhilopt', 'achitophel'),
#  ('aaadinoptt', 'adaptation'),
#  ('abbdeors', 'absorbed'),
#  ('aaccdejny', 'adjacency'),
#  ('aabdeilmr', 'admirable'),
#  ('addeisv', 'advised'),
#  ('aeehoprty', 'aerophyte'),
#  ('aefir', 'afire'),
#  ('aaeegno', 'aegaeon'),
#  ('acchiimnooprt', 'actinomorphic'),
#  ('aacdefinrr', 'africander'),
#  ('aceehiimsstt', 'aestheticism'),
#  ('aaaaabbcdrr', 'abracadabra'),
#  ('aeeehoprrs', 'aerosphere'),
#  ('adeinorsuv', 'adenovirus'),
#  ('aaeeeghmoooprrrt', 'aerometeorograph'),
#  ('aabist', 'abatis'),
#  ('aceeffhinnprs', 'affenpinscher'),
#  ('aabenrrt', 'aberrant'),
#  ('abiioss', 'abiosis'),
#  ('acdeeiimrt', 'acidimeter'),
#  ('acdjntu', 'adjunct'),
#  ('aacccnnotuy', 'accountancy'),
#  ('abdnou', 'abound'),
#  ('aflou', 'afoul'),
#  ('aceenot', 'acetone'),
#  ('aabiimnnoot', 'abomination'),
#  ('aby', 'aby'),
#  ('abeeeimnsst', 'absenteeism'),
#  ('acdeelnost', 'adolescent'),
#  ('acceinort', 'accretion'),
#  ('adeeinn', 'adenine'),
#  ('abelosv', 'absolve'),
#  ('accdor', 'accord'),
#  ('aahrsu', 'aarhus'),
#  ('adeimnr', 'adermin'),
#  ('aabcdeery', 'abecedary'),
#  ('acemtu', 'acetum'),
#  ('acdhiilop', 'acidophil'),
#  ('aaeilot', 'aetolia'),
#  ('aadeimst', 'adamsite'),
#  ('aaabhmr', 'abraham'),
#  ('affiinty', 'affinity'),
#  ('aaccenptt', 'acceptant'),
#  ('aabenty', 'abeyant'),
#  ('acgint', 'acting'),
#  ('aadino', 'adonai'),
#  ('abellostuy', 'absolutely'),
#  ('adeeinnos', 'adenosine'),
#  ('acdddeit', 'addicted'),
#  ('abeefilr', 'afebrile'),
#  ('aacceilmtuuv', 'accumulative'),
#  ('accehiimnorstty', 'actinochemistry'),
#  ('aaabcdiit', 'adiabatic'),
#  ('accmostu', 'accustom'),
#  ('aceeemortt', 'acetometer'),
#  ('aaaccehnostu', 'acanthaceous'),
#  ('aadmn', 'adman'),
#  ('aabelz', 'ablaze'),
#  ('adelrtuy', 'adultery'),
#  ('abinoprtu', 'abruption'),
#  ('aabceert', 'acerbate'),
#  ('aaccilnorttuu', 'acculturation'),
#  ('acciimnnoty', 'actinomycin'),
#  ('aaaccilmnot', 'acclamation'),
#  ('abeisuv', 'abusive'),
#  ('aceffiiltv', 'afflictive'),
#  ('aceh', 'ache'),
#  ('aabck', 'aback'),
#  ('aacdeotv', 'advocate'),
#  ('aaabrsx', 'abraxas'),
#  ('aadr', 'adar'),
#  ('addiorty', 'additory'),
#  ('acdir', 'acrid'),
#  ('acdeiinr', 'acridine'),
#  ('aadeilnnr', 'adrenalin'),
#  ('aaffiimnort', 'affirmation'),
#  ('aaccelmtuu', 'accumulate')]

# %%
res1.saveAsTextFile('res-words-filtered')
res2.saveAsTextFile('res-words-unfiltered')

# %% [markdown]
# Let's check that the results were written on HDFS:

# %%
# !hadoop fs -ls res-words-filtered
# Out:
# Found 3 items
# -rw-r--r--   1 vagrant supergroup          0 2022-12-27 10:40 res-words-filtered/_SUCCESS
# -rw-r--r--   1 vagrant supergroup         69 2022-12-27 10:40 res-words-filtered/part-00000
# -rw-r--r--   1 vagrant supergroup        197 2022-12-27 10:40 res-words-filtered/part-00001

# %%
# !hadoop fs -ls res-words-unfiltered
# Out:
# Found 3 items
# -rw-r--r--   1 vagrant supergroup          0 2022-12-27 10:41 res-words-unfiltered/_SUCCESS
# -rw-r--r--   1 vagrant supergroup      12660 2022-12-27 10:41 res-words-unfiltered/part-00000
# -rw-r--r--   1 vagrant supergroup      12883 2022-12-27 10:40 res-words-unfiltered/part-00001

# %%
# !hadoop fs -cat res-words-filtered/*
# Out:
# ('abhmo', 'abohm, abmho')
# ('ace', 'aec, ace')
# ('abel', 'abel, able')
# ('deer', 'deer, reed')
# ('aabdor', 'aboard, abroad')
# ('elmno', 'lemon, melon')
# ('acceortu', 'accoutre, accouter')
# ('abilnotu', 'ablution, abutilon')
# ('aekl', 'leak, lake')
# ('abdeo', 'abode, adobe')

# %%
# !hadoop fs -cat res-words-unfiltered/*
# Out:
# ('adeenory', 'aerodyne')
# ('aceehn', 'achene')
# ('abcesss', 'abscess')
# ('adnor', 'adorn')
# ('adfirt', 'adrift')
# ('aabdeorst', 'adsorbate')
# ('aceeimnqrtu', 'acquirement')
# ('acehnor', 'acheron')
# ('abhmo', 'abohm, abmho')
# ('aaagru', 'aargau')
# ('aacilttuy', 'actuality')
# ('aabcciorst', 'acrobatics')
# ('aacceinoptt', 'acceptation')
# ('aaffiln', 'affinal')
# ('adeein', 'aeneid')
# ('aciqtu', 'acquit')
# ('aaafiknrs', 'afrikaans')
# ('aabdnntu', 'abundant')
# ('abcdentu', 'abducent')
# ('acdnoort', 'acrodont')
# ('aceloty', 'acolyte')
# ('aaabbilt', 'abbatial')
# ('aaddms', 'addams')
# ('aeeimtt', 'teatime')
# ('adeersv', 'adverse')
# ('aadefr', 'afeard')
# ('aefghhortttu', 'afterthought')
# ('aaaceh', 'achaea')
# ('aabccelnotu', 'accountable')
# ('abceirty', 'acerbity')
# ('aaccooprrsu', 'acrocarpous')
# ('adjstu', 'adjust')
# ('accnotu', 'account')
# ('aacefiinrz', 'africanize')
# ('aacdeeilmor', 'aeromedical')
# ('ademstu', 'admetus')
# ('aaceimntu', 'acuminate')
# ('aa', 'aa')
# ('aaabcdeeinr', 'abecedarian')
# ('accdeint', 'accident')
# ('aaffiinotx', 'affixation')
# ('aaceiorstt', 'aerostatic')
# ('aabchioopr', 'acrophobia')
# ('aabcsu', 'abacus')
# ('aaegin', 'aegina')
# ('aacceiltu', 'aciculate')
# ('aacclru', 'accrual')
# ('aacilnr', 'acrilan')
# ('aacceelnrt', 'accelerant')
# ('aeehnoopr', 'aerophone')
# ('abehnry', 'abhenry')
# ('aabeemntt', 'abatement')
# ('aacdeeimt', 'acetamide')
# ('acemnu', 'acumen')
# ('abdegir', 'abridge')
# ('adeehisv', 'adhesive')
# ('aceeefiprt', 'afterpiece')
# ('acdiiiossttu', 'adscititious')
# ('adp', 'adp')
# ('aaafghinnst', 'afghanistan')
# ('aadeilnopr', 'adrianople')
# ('aaaccceiltt', 'acatalectic')
# ('abelnsty', 'absently')
# ('acehlosu', 'achelous')
# ('abcdins', 'abscind')
# ('aciittvy', 'activity')
# ('aaeiilrst', 'aerialist')
# ('acccdeiinooooprrrtt', 'adrenocorticotropic')
# ('acdeefkrt', 'afterdeck')
# ('aacdei', 'acedia')
# ('abiinoorstt', 'abortionist')
# ('aceeehimntv', 'achievement')
# ('adeiimnrst', 'administer')
# ('aacceenttu', 'accentuate')
# ('aaceloprt', 'acropetal')
# ('aaddx', 'addax')
# ('aegloory', 'aerology')
# ('aceinot', 'aconite')
# ('adder', 'adder')
# ('acdinoopt', 'actinopod')
# ('aaceehillstty', 'aesthetically')
# ('aeor', 'aero')
# ('aeno', 'aeon')
# ('aceilo', 'aeolic')
# ('aadfir', 'afraid')
# ('adimx', 'admix')
# ('aefmorstt', 'aftermost')
# ('aabinst', 'abstain')
# ('aceehisstt', 'aesthetics')
# ('aaaeghiopr', 'aerophagia')
# ('aefrt', 'after')
# ('aadilmrty', 'admiralty')
# ('acdeinotv', 'advection')
# ('aadeprt', 'adapter')
# ('aabhs', 'abash')
# ('acdeefft', 'affected')
# ('addeiitv', 'additive')
# ('accdeeelnos', 'adolescence')
# ('aceimu', 'aecium')
# ('aaddeghoprrss', 'addressograph')
# ('aeffoosttu', 'affettuoso')
# ('aadeg', 'adage')
# ('addinos', 'addison')
# ('affnort', 'affront')
# ('acdilosuu', 'acidulous')
# ('acdiinoprst', 'adscription')
# ('aciimnst', 'actinism')
# ('aabdelor', 'adorable')
# ('affinosu', 'affusion')
# ('aceitv', 'active')
# ('aacdejnt', 'adjacent')
# ('accilmuu', 'aciculum')
# ('aalot', 'aalto')
# ('aadinr', 'adrian')
# ('abiruzz', 'abruzzi')
# ('aaadeimnnt', 'adamantine')
# ('abimnorty', 'abnormity')
# ('abprtu', 'abrupt')
# ('aabbdeoorv', 'aboveboard')
# ('acdeeijtv', 'adjective')
# ('acceinoss', 'accession')
# ('aeops', 'aesop')
# ('aadeemrsu', 'admeasure')
# ('adltu', 'adult')
# ('aablmnor', 'abnormal')
# ('aeefimrtt', 'aftertime')
# ('aaeiinosttv', 'aestivation')
# ('aacchimort', 'achromatic')
# ('aaeffiimrtv', 'affirmative')
# ('abikru', 'abukir')
# ('aaciorttv', 'activator')
# ('aacdhinot', 'acanthoid')
# ('acdeeiopr', 'adipocere')
# ('abiilnoot', 'abolition')
# ('aacinqtu', 'acquaint')
# ('aaeilr', 'aerial')
# ('aadeeilnnr', 'adrenaline')
# ('acdeilntu', 'acidulent')
# ('accdii', 'acidic')
# ('aacdim', 'adamic')
# ('abenst', 'absent')
# ('abeov', 'above')
# ('aaccilu', 'acicula')
# ('accdgilnory', 'accordingly')
# ('acnot', 'acton')
# ('aceiloooprt', 'aeolotropic')
# ('abefginnrrtu', 'afterburning')
# ('aadjntuv', 'adjuvant')
# ('aabefinrrt', 'afterbrain')
# ('acllryy', 'acrylyl')
# ('acdeeilty', 'acetylide')
# ('aaacdotv', 'advocaat')
# ('aaccerssy', 'accessary')
# ('abeiioorss', 'aerobiosis')
# ('aabdeerr', 'aberdare')
# ('ace', 'aec, ace')
# ('aaeflm', 'aflame')
# ('affghirt', 'affright')
# ('abinooprst', 'absorption')
# ('aciisttv', 'activist')
# ('aacceiilmtz', 'acclimatize')
# ('abesu', 'abuse')
# ('aabelno', 'abalone')
# ('abdosy', 'abydos')
# ('aacoprsu', 'acarpous')
# ('aaadp', 'adapa')
# ('aacdeehimmnoorrsty', 'aerothermodynamics')
# ('aabeffl', 'affable')
# ('abersstu', 'abstruse')
# ('aceefflnu', 'affluence')
# ('aadinoort', 'adoration')
# ('acdijnnotu', 'adjunction')
# ('acdeeehnr', 'adherence')
# ('aceehiv', 'achieve')
# ('aacdeehimn', 'achaemenid')
# ('aegilooty', 'aetiology')
# ('aaceffinott', 'affectation')
# ('abdgiin', 'abiding')
# ('achilort', 'acrolith')
# ('accceilmop', 'accomplice')
# ('acimtu', 'actium')
# ('aaabdn', 'abadan')
# ('aaeinno', 'aeonian')
# ('aeeilort', 'aerolite')
# ('adeeefimnnoort', 'aforementioned')
# ('adeehnrt', 'adherent')
# ('aabcert', 'abreact')
# ('aabcenoprst', 'absorptance')
# ('acciostu', 'acoustic')
# ('abceiss', 'abscise')
# ('abel', 'abel, able')
# ('aabiinrrtt', 'abirritant')
# ('aaceeehioprrsttu', 'aerotherapeutics')
# ('aabdelr', 'abelard')
# ('1a', 'a1')
# ('aaciimnnortuu', 'actinouranium')
# ('abcer', 'acerb')
# ('aceeiooprs', 'aeciospore')
# ('aabdijn', 'abidjan')
# ('aaceffhinrs', 'affranchise')
# ('acdeegklnow', 'acknowledge')
# ('aaaceilnpsu', 'aesculapian')
# ('abeeiln', 'abilene')
# ('adeeisv', 'advisee')
# ('aablmos', 'absalom')
# ('accdeii', 'accidie')
# ('aaccdeimmootv', 'accommodative')
# ('abotu', 'about')
# ('adeimr', 'admire')
# ('aam', 'aam')
# ('adeioptv', 'adoptive')
# ('acegnor', 'acrogen')
# ('aabcceelpt', 'acceptable')
# ('aaeorrt', 'aerator')
# ('aabcefiinortt', 'abortifacient')
# ('aabeegnt', 'abnegate')
# ('aabbeiinortv', 'abbreviation')
# ('aeeffilrt', 'afterlife')
# ('aaceeltty', 'acetylate')
# ('aaegortt', 'aegrotat')
# ('addden', 'addend')
# ('acceeiqsu', 'acquiesce')
# ('aaabilx', 'abaxial')
# ('aadghinrt', 'adigranth')
# ('abddeeimnnst', 'absentminded')
# ('aaderrsvy', 'adversary')
# ('abeeissv', 'abessive')
# ('aabilou', 'aboulia')
# ('aabceilnot', 'actionable')
# ('adeor', 'adore')
# ('aacetu', 'acuate')
# ('aabnnost', 'absonant')
# ('acccehoruu', 'accoucheur')
# ('aaccfiimnor', 'acinaciform')
# ('affimr', 'affirm')
# ('abdei', 'abide')
# ('adeenrrtuv', 'adventurer')
# ('aachmort', 'achromat')
# ('aaccmnopy', 'accompany')
# ('aaccdovy', 'advocacy')
# ('acelsuu', 'aculeus')
# ('aaeeisttv', 'aestivate')
# ('aacfiinrst', 'africanist')
# ('aadmss', 'admass')
# ('adit', 'adit')
# ('adeeilnrtu', 'adulterine')
# ('aacdior', 'acaroid')
# ('accenprtuuu', 'acupuncture')
# ('aaccimnopsty', 'accompanyist')
# ('aceffinot', 'affection')
# ('abbors', 'absorb')
# ('aaccdgimmnoot', 'accommodating')
# ('aeegsu', 'aegeus')
# ('aaeens', 'aeneas')
# ('acciimnoossty', 'actinomycosis')
# ('aacclsu', 'accusal')
# ('aabcinorstt', 'abstraction')
# ('aaabdelpt', 'adaptable')
# ('aden', 'aden')
# ('adeiu', 'adieu')
# ('aaccdeiir', 'acaricide')
# ('aery', 'aery')
# ('adeeirstv', 'advertise')
# ('acceiiprt', 'accipiter')
# ('acis', 'acis')
# ('aadefrrstw', 'afterwards')
# ('aadeiimnrstt', 'administrate')
# ('acgilnooty', 'actinology')
# ('adeisv', 'advise')
# ('aademno', 'adenoma')
# ('acddeu', 'adduce')
# ('acdiioss', 'acidosis')
# ('acht', 'acth')
# ('aacdhhilorry', 'achlorhydria')
# ('accceehmnotu', 'accouchement')
# ('aab', 'aba')
# ('aabciimnorsstt', 'abstractionism')
# ('aaeilno', 'aeolian')
# ('aaeorstt', 'aerostat')
# ('abdenorst', 'adsorbent')
# ('accdemostu', 'accustomed')
# ('acceeinqstu', 'acquiescent')
# ('act', 'act')
# ('aabekotu', 'abeokuta')
# ('abbess', 'abbess')
# ('accenort', 'accentor')
# ('aachimnort', 'achromatin')
# ('aabiortt', 'abattoir')
# ('aacccruy', 'accuracy')
# ('acddeeimnooty', 'adenoidectomy')
# ('aceeimnortt', 'actinometer')
# ('aaffry', 'affray')
# ('aaceflprt', 'afterclap')
# ('abceehnorr', 'abhorrence')
# ('aceeooprs', 'aeroscope')
# ('aabceiillorsst', 'aeroballistics')
# ('acceehillnoty', 'acetylcholine')
# ('aefhrs', 'afresh')
# ('aadeiinttv', 'adventitia')
# ('aaddeilno', 'adenoidal')
# ('aaadkrrv', 'aardvark')
# ('aaccdnort', 'accordant')
# ('aabilu', 'abulia')
# ('adimnoorty', 'admonitory')
# ('acituy', 'acuity')
# ('aablssy', 'abyssal')
# ('af', 'af')
# ('aaceett', 'acetate')
# ('aadm', 'adam')
# ('aaadmnt', 'adamant')
# ('addeilmtty', 'admittedly')
# ('aciimntu', 'actinium')
# ('aaccd', 'accad')
# ('abcceeilss', 'accessible')
# ('abeinnostt', 'abstention')
# ('aaent', 'aetna')
# ('aaccdeim', 'academic')
# ('aaeert', 'aerate')
# ('acdeemnoty', 'adenectomy')
# ('aeeir', 'aerie')
# ('aabgiilnor', 'aboriginal')
# ('aacddiijnotu', 'adjudication')
# ('abdegnooruv', 'aboveground')
# ('admtuy', 'adytum')
# ('abdirstuy', 'absurdity')
# ('aabgiil', 'abigail')
# ('addiinot', 'addition')
# ('aeflrttu', 'aflutter')
# ('aeeimrt', 'meatier')
# ('abbenorst', 'absorbent')
# ('acceeprt', 'accepter')
# ('aabcist', 'abacist')
# ('acceit', 'acetic')
# ('acen', 'acne')
# ('adeenrsstuv', 'adventuress')
# ('acly', 'acyl')
# ('acdeiv', 'advice')
# ('accost', 'accost')
# ('aciimstv', 'activism')
# ('acefft', 'affect')
# ('abhor', 'abhor')
# ('aaeghoprry', 'aerography')
# ('aacddenv', 'advanced')
# ('abcdinotu', 'abduction')
# ('abdginno', 'abingdon')
# ('aadiimnorrstt', 'administrator')
# ('aanor', 'aaron')
# ('aceiqru', 'acquire')
# ('abegiinor', 'aborigine')
# ('aaceffiirtv', 'affricative')
# ('abdors', 'adsorb')
# ('aacdeijltv', 'adjectival')
# ('aacceehimnor', 'aeromechanic')
# ('aaeffir', 'affaire')
# ('aceinoorrt', 'acroterion')
# ('aabes', 'abase')
# ('aabeiirrtt', 'abirritate')
# ('aaccelrttuu', 'acculturate')
# ('aadjnttu', 'adjutant')
# ('aacdfiinoo', 'aficionado')
# ('abcceir', 'acerbic')
# ('adnoosvw', 'advowson')
# ('acciint', 'actinic')
# ('aabbeilmno', 'abominable')
# ('aabeilps', 'ablepsia')
# ('aabeinorrt', 'aberration')
# ('acdeno', 'acnode')
# ('abtu', 'abut')
# ('ab', 'ab')
# ('acetu', 'acute')
# ('aaacceinnqtu', 'acquaintance')
# ('aacdeemnntv', 'advancement')
# ('adopt', 'adopt')
# ('abdhiit', 'adhibit')
# ('aaeeimnorr', 'aeromarine')
# ('acdeegklmnnotw', 'acknowledgment')
# ('addeopt', 'adopted')
# ('aacdequy', 'adequacy')
# ('aacehlopsu', 'acephalous')
# ('acciosstu', 'acoustics')
# ('aaacdhilnooprs', 'achondroplasia')
# ('acffiilnot', 'affliction')
# ('adelr', 'adler')
# ('aabeirsv', 'abrasive')
# ('aaccertu', 'accurate')
# ('afirt', 'afrit')
# ('adeelrsstu', 'adulteress')
# ('abccemntu', 'accumbent')
# ('adimt', 'admit')
# ('aceiiiqstuv', 'acquisitive')
# ('aacceelnstu', 'acaulescent')
# ('acinnot', 'actinon')
# ('aadms', 'adams')
# ('abcdtu', 'abduct')
# ('aaadilru', 'adularia')
# ('aabcisss', 'abscissa')
# ('adez', 'adze')
# ('abilnoostu', 'absolution')
# ('aaabelqsttuu', 'absquatulate')
# ('adelorstuu', 'adulterous')
# ('acehills', 'achilles')
# ('aabb', 'abba')
# ('aaabc', 'abaca')
# ('acceenst', 'acescent')
# ('abc', 'abc')
# ('aacehst', 'achates')
# ('aabegort', 'abrogate')
# ('adeimrtux', 'admixture')
# ('ado', 'ado')
# ('acmnory', 'acronym')
# ('aceeors', 'acerose')
# ('adeiimssv', 'admissive')
# ('aacrtuy', 'actuary')
# ('aadefrrtw', 'afterward')
# ('aaffirs', 'affairs')
# ('acinot', 'action')
# ('aacdeimntt', 'admittance')
# ('accent', 'accent')
# ('acceilrtuuz', 'acculturize')
# ('aaccelntu', 'accentual')
# ('aafflstu', 'afflatus')
# ('adeehr', 'adhere')
# ('aabinors', 'abrasion')
# ('aaccdelo', 'accolade')
# ('abdemno', 'abdomen')
# ('aaeilstv', 'aestival')
# ('abssy', 'abyss')
# ('abeegnrstt', 'abstergent')
# ('acdeiilmn', 'adminicle')
# ('aafghn', 'afghan')
# ('acefhkorst', 'aftershock')
# ('aacfir', 'africa')
# ('aabdeilrv', 'adverbial')
# ('aabehioopr', 'aerophobia')
# ('aacdeiltu', 'acidulate')
# ('aaccilmnotuu', 'accumulation')
# ('acddiinot', 'addiction')
# ('aefnnoorst', 'afternoons')
# ('aceioprrs', 'acrospire')
# ('aeefimort', 'aforetime')
# ('abceens', 'absence')
# ('aaacci', 'acacia')
# ('abbi', 'abib')
# ('aelosu', 'aeolus')
# ('aadeeirstvv', 'adversative')
# ('aefimorr', 'aeriform')
# ('aacceehimnors', 'aeromechanics')
# ('aaiil', 'aalii')
# ('aadeenru', 'adenauer')
# ('aaccorstuy', 'accusatory')
# ('aacddeeehlty', 'acetaldehyde')
# ('aaccimnopst', 'accompanist')
# ('aabiinssy', 'abyssinia')
# ('aaeffiilt', 'affiliate')
# ('aefor', 'afore')
# ('aciiinoqstu', 'acquisition')
# ('aabcelmtuu', 'acetabulum')
# ('abceeinnst', 'abstinence')
# ('accdersu', 'accursed')
# ('aadow', 'adowa')
# ('abdeegno', 'abednego')
# ('ably', 'ably')
# ('abcdeu', 'abduce')
# ('abbclmoou', 'abcoulomb')
# ('aaabdnrt', 'abradant')
# ('aabceiorst', 'aerobatics')
# ('acersst', 'actress')
# ('abbey', 'abbey')
# ('abort', 'abort')
# ('abciinorstt', 'abstriction')
# ('aacceistuv', 'accusative')
# ('acdiity', 'acidity')
# ('aceehistt', 'aesthetic')
# ('accilry', 'acrylic')
# ('adegiinrstv', 'advertising')
# ('aaacdi', 'acadia')
# ('abdrsu', 'absurd')
# ('aafr', 'afar')
# ('aabbceefinorst', 'absorbefacient')
# ('accehilmmnopst', 'accomplishment')
# ('aaaaccccirtu', 'acciaccatura')
# ('acnor', 'acorn')
# ('aabeempr', 'abampere')
# ('aablsttu', 'abuttals')
# ('adept', 'adept')
# ('aacettu', 'actuate')
# ('aabilnot', 'ablation')
# ('aaccilru', 'acicular')
# ('aadent', 'adnate')
# ('aafghin', 'afghani')
# ('abciinosss', 'abscission')
# ('abehnorrt', 'abhorrent')
# ('aaceegr', 'acreage')
# ('aabeiltv', 'ablative')
# ('acceeimnotty', 'actinomycete')
# ('adeforrtw', 'afterword')
# ('acer', 'acre')
# ('aabceinort', 'abreaction')
# ('acccily', 'acyclic')
# ('acdiinot', 'actinoid')
# ('aciimnoorsu', 'acrimonious')
# ('aaaciirss', 'acariasis')
# ('aaclltuy', 'actually')
# ('aabmmosu', 'abomasum')
# ('acceinrt', 'acentric')
# ('abeeenst', 'absentee')
# ('aaeefhrtt', 'afterheat')
# ('aabbdeeirtv', 'abbreviated')
# ('aft', 'aft')
# ('aacceelorrt', 'accelerator')
# ('afoot', 'afoot')
# ('aaeegn', 'aegean')
# ('acimnory', 'acrimony')
# ('aeeiillop', 'aeolipile')
# ('aaceeffinott', 'affectionate')
# ('aefghhoorttu', 'aforethought')
# ('aadeelrttu', 'adulterate')
# ('adnow', 'adown')
# ('abeel', 'abele')
# ('aaeinoorstt', 'aerostation')
# ('afor', 'afro')
# ('aacceimmnnopt', 'accompaniment')
# ('adeflorrtw', 'afterworld')
# ('aabelt', 'ablate')
# ('abcdnos', 'abscond')
# ('aaceiorsstt', 'aerostatics')
# ('aeghisstu', 'aegisthus')
# ('acelty', 'acetyl')
# ('aacdeinqtu', 'acquainted')
# ('aabcderstt', 'abstracted')
# ('abceior', 'aerobic')
# ('abbeorrs', 'absorber')
# ('acimnoor', 'acromion')
# ('aaefiknrr', 'afrikaner')
# ('acddeiitv', 'addictive')
# ('aacceinnottu', 'accentuation')
# ('a', 'a')
# ('accceenrst', 'accrescent')
# ('addegju', 'adjudge')
# ('aadeilnorttu', 'adulteration')
# ('aabddenno', 'abandoned')
# ('deer', 'deer, reed')
# ('aaccdeiimms', 'academicism')
# ('aaffint', 'affiant')
# ('aadeeemmnrstu', 'admeasurement')
# ('aaccchor', 'accroach')
# ('aaberst', 'abreast')
# ('acceru', 'accrue')
# ('accdeirt', 'accredit')
# ('adeeimnstv', 'advisement')
# ('aadddeelpt', 'addlepated')
# ('aegir', 'aegir')
# ('acfiimnort', 'actiniform')
# ('aacdehlmosuy', 'achlamydeous')
# ('aadegiott', 'adagietto')
# ('acceert', 'accrete')
# ('aabft', 'abaft')
# ('aefiry', 'aerify')
# ('adejru', 'adjure')
# ('aaceeltu', 'aculeate')
# ('adijnot', 'adjoint')
# ('aacdilntu', 'acidulant')
# ('aadefiknrr', 'afrikander')
# ('abilmosstu', 'absolutism')
# ('aabbeiillnv', 'abbevillian')
# ('aeilos', 'aeolis')
# ('abuzz', 'abuzz')
# ('aaenortu', 'aeronaut')
# ('aadiimnort', 'admiration')
# ('aabmp', 'abamp')
# ('adejmnnortu', 'adjournment')
# ('acdeeehiinnoptt', 'acetophenetidin')
# ('aadefgrrtu', 'afterguard')
# ('adeiops', 'adipose')
# ('acefity', 'acetify')
# ('abdeeenr', 'aberdeen')
# ('aaaccdeiimn', 'academician')
# ('adeffin', 'affined')
# ('aabceeny', 'abeyance')
# ('adiimnnoot', 'admonition')
# ('abderv', 'adverb')
# ('aabttw', 'abwatt')
# ('aadiiimnnorstt', 'administration')
# ('aaflot', 'afloat')
# ('addhlootu', 'adulthood')
# ('aaabdfr', 'abfarad')
# ('abiioprsttvy', 'absorptivity')
# ('abeklmos', 'abelmosk')
# ('adijno', 'adjoin')
# ('aabdis', 'abdias')
# ('accdehilmops', 'accomplished')
# ('abdeforty', 'afterbody')
# ('abeils', 'abseil')
# ('adeimnrstuv', 'adventurism')
# ('aaccdemmoot', 'accommodate')
# ('aadefiors', 'aforesaid')
# ('aacdeffin', 'affianced')
# ('aabcdennu', 'abundance')
# ('aadeeqtu', 'adequate')
# ('aberttu', 'abutter')
# ('aaeeoprsu', 'aeropause')
# ('aacehn', 'aachen')
# ('aacilnt', 'actinal')
# ('aeeehstt', 'aesthete')
# ('aadilnotu', 'adulation')
# ('aabltu', 'ablaut')
# ('accdesu', 'accused')
# ('adeemoorr', 'aerodrome')
# ('acddtu', 'adduct')
# ('aachnstu', 'acanthus')
# ('affix', 'affix')
# ('aaacdlu', 'acaudal')
# ('abiilty', 'ability')
# ('aaacdin', 'acadian')
# ('adinos', 'adonis')
# ('acfiimnor', 'aciniform')
# ('aceorrt', 'acroter')
# ('aadeinoort', 'aerodontia')
# ('aaadegntv', 'advantage')
# ('aaeehisst', 'aesthesia')
# ('aeffin', 'affine')
# ('aablmsy', 'abysmal')
# ('aabdnno', 'abandon')
# ('aadelnrttu', 'adulterant')
# ('aabbdis', 'abbasid')
# ('abegilooory', 'aerobiology')
# ('aabilmnorty', 'abnormality')
# ('aaceilpssuu', 'aesculapius')
# ('aceiilnott', 'actinolite')
# ('aaccnnottu', 'accountant')
# ('acceelmnoptu', 'accouplement')
# ('accdeept', 'accepted')
# ('addginnot', 'addington')
# ('aaeelnopr', 'aeroplane')
# ('acchimor', 'achromic')
# ('aabdeilsv', 'advisable')
# ('abeiortv', 'abortive')
# ('aacelt', 'acetal')
# ('adiorsvy', 'advisory')
# ('acdehinort', 'achondrite')
# ('aaceittv', 'activate')
# ('aabdor', 'aboard, abroad')
# ('aacddeijtu', 'adjudicate')
# ('abcejt', 'abject')
# ('aaceefrrt', 'aftercare')
# ('aacdemy', 'academy')
# ('aacemnory', 'aeromancy')
# ('aaccilm', 'acclaim')
# ('aacdlostuy', 'adactylous')
# ('adefil', 'afield')
# ('abeimosstu', 'abstemious')
# ('aacceilmt', 'acclimate')
# ('acceorssy', 'accessory')
# ('abbginors', 'absorbing')
# ('aaciint', 'actinia')
# ('addel', 'addle')
# ('aaffir', 'affair')
# ('aabciinorssttt', 'abstractionist')
# ('aefglortw', 'afterglow')
# ('aabder', 'abrade')
# ('aadeimt', 'adamite')
# ('accginnotu', 'accounting')
# ('aaceinorstu', 'aeronautics')
# ('acchilmops', 'accomplish')
# ('aabddno', 'abaddon')
# ('acciiltvy', 'acclivity')
# ('acdino', 'adonic')
# ('accceeeinqsu', 'acquiescence')
# ('aaaccgnou', 'aconcagua')
# ('aacehnrr', 'achernar')
# ('eeimrtt', 'termite')
# ('abehinst', 'absinthe')
# ('aabdilmno', 'abdominal')
# ('aaadn', 'adana')
# ('aceiillnorrty', 'acrylonitrile')
# ('aaacdehimnrty', 'adiathermancy')
# ('aacdeeiilnt', 'acetanilide')
# ('aceeelnty', 'acetylene')
# ('abeortt', 'abettor')
# ('aacceeilnort', 'acceleration')
# ('aeeemorrt', 'aerometer')
# ('abefhirrtt', 'afterbirth')
# ('abdimnoosu', 'abdominous')
# ('aacehlp', 'acaleph')
# ('abm', 'abm')
# ('aabcdeeimru', 'abecedarium')
# ('aadpt', 'adapt')
# ('aadilmr', 'admiral')
# ('aaceeirt', 'acierate')
# ('acorss', 'across')
# ('acccdeein', 'accidence')
# ('adertv', 'advert')
# ('adegi', 'adige')
# ('accdee', 'accede')
# ('aadefmprt', 'afterdamp')
# ('aacefiilnrv', 'acriflavine')
# ('aaddeimntt', 'additament')
# ('aaccinostu', 'accusation')
# ('elmno', 'lemon, melon')
# ('aefflntu', 'affluent')
# ('aacdenv', 'advance')
# ('adeenrtuv', 'adventure')
# ('aalst', 'aalst')
# ('adstu', 'adust')
# ('acilooprs', 'acropolis')
# ('aabikn', 'abnaki')
# ('aaffimorrty', 'affirmatory')
# ('ac', 'ac')
# ('aceehinss', 'aeschines')
# ('aacdir', 'acarid')
# ('aceffgint', 'affecting')
# ('aacdeimnorsy', 'aerodynamics')
# ('aaccdeelnor', 'accelerando')
# ('abir', 'abri')
# ('adeeil', 'aedile')
# ('adderss', 'address')
# ('aabglor', 'aalborg')
# ('aacchiimortty', 'achromaticity')
# ('aablor', 'aboral')
# ('aaccceenpt', 'acceptance')
# ('aefforst', 'afforest')
# ('adeirsv', 'adviser')
# ('acceortu', 'accoutre, accouter')
# ('acdeeinoorst', 'aerodonetics')
# ('aeeinoorrssu', 'aeroneurosis')
# ('aadeiptv', 'adaptive')
# ('aachimmorst', 'achromatism')
# ('abdegimnrt', 'abridgment')
# ('aacdinootv', 'advocation')
# ('aacceinqttu', 'acquittance')
# ('aaadeirrsv', 'adversaria')
# ('aaadilx', 'adaxial')
# ('aacccdenor', 'accordance')
# ('aaadimny', 'adynamia')
# ('adenorstuuv', 'adventurous')
# ('aaduw', 'aduwa')
# ('acem', 'acme')
# ('acceeeelmorrt', 'accelerometer')
# ('aadeiiimnrsttv', 'administrative')
# ('aadflorw', 'aardwolf')
# ('acinsu', 'acinus')
# ('accept', 'accept')
# ('aaeffhrstt', 'aftershaft')
# ('acceemnorttu', 'accouterment')
# ('abbot', 'abbot')
# ('aeenosu', 'aeneous')
# ('aaadegnostuv', 'advantageous')
# ('addeeerss', 'addressee')
# ('aacclmortuu', 'accumulator')
# ('aegpstuy', 'aegyptus')
# ('aaacehn', 'achaean')
# ('aeehrt', 'aether')
# ('acddortu', 'adductor')
# ('aacinnootz', 'actinozoan')
# ('abhilos', 'abolish')
# ('abemnttu', 'abutment')
# ('aabet', 'abate')
# ('adeimnopt', 'ademption')
# ('aacehinoprtty', 'actinotherapy')
# ('aceilnor', 'acrolein')
# ('aaacdelm', 'aceldama')
# ('adejmnsttu', 'adjustment')
# ('adeeeimnrsttv', 'advertisement')
# ('abejru', 'abjure')
# ('aacinor', 'aaronic')
# ('aacclopu', 'acapulco')
# ('aacrsu', 'acarus')
# ('abilnotu', 'ablution, abutilon')
# ('aacceeelrt', 'accelerate')
# ('aaeefgimrt', 'afterimage')
# ('aeefrt', 'afreet')
# ('aabcort', 'acrobat')
# ('aabdddeeilnr', 'addlebrained')
# ('aaefhmrtt', 'aftermath')
# ('abelostu', 'absolute')
# ('acint', 'actin')
# ('acdeeenrtv', 'advertence')
# ('acciorst', 'acrostic')
# ('adddemnu', 'addendum')
# ('aabcdiinot', 'abdication')
# ('aabcciort', 'acrobatic')
# ('aaaaccehhlnnopt', 'acanthocephalan')
# ('aaceert', 'acerate')
# ('aaegmorr', 'aerogram')
# ('addeilsvy', 'advisedly')
# ('acddinotu', 'adduction')
# ('aceeefffrtt', 'aftereffect')
# ('aaccdimmnooot', 'accommodation')
# ('adeirstvy', 'adversity')
# ('add', 'add')
# ('aabbeeirtv', 'abbreviate')
# ('adeinsttv', 'adventist')
# ('aeloors', 'aerosol')
# ('adgiijnno', 'adjoining')
# ('adjnoru', 'adjourn')
# ('acimnoosty', 'actomyosin')
# ('aefnnoort', 'afternoon')
# ('aaaccdeimnnoor', 'adenocarcinoma')
# ('acdeiimrty', 'acidimetry')
# ('aaeefinnorsstt', 'aftersensation')
# ('accdginor', 'according')
# ('ad', 'ad')
# ('addeino', 'adenoid')
# ('aekl', 'leak, lake')
# ('abeegiinoss', 'abiogenesis')
# ('aaceeoprs', 'aerospace')
# ('aceostu', 'acetous')
# ('aaaceghinnoprtty', 'acanthopterygian')
# ('aabeimnot', 'abominate')
# ('aeffiiintv', 'affinitive')
# ('acdelnooty', 'acotyledon')
# ('acffilt', 'afflict')
# ('aaceiltuz', 'actualize')
# ('aaccentu', 'acutance')
# ('adhimnos', 'admonish')
# ('aacilqttu', 'acquittal')
# ('aabijnortu', 'abjuration')
# ('abhiimnsst', 'absinthism')
# ('aaffiiilnot', 'affiliation')
# ('adeiinosttuv', 'adventitious')
# ('aadgio', 'adagio')
# ('afflux', 'afflux')
# ('aacenot', 'actaeon')
# ('adios', 'adios')
# ('aabcelt', 'actable')
# ('adeeissv', 'adessive')
# ('aceeffitv', 'affective')
# ('aaeghoprr', 'aerograph')
# ('abb', 'abb')
# ('aaceertv', 'acervate')
# ('aacefiiinort', 'aerification')
# ('abcdortu', 'abductor')
# ('aeirs', 'aesir')
# ('aabdemrtu', 'adumbrate')
# ('aabcrstt', 'abstract')
# ('aegoru', 'aerugo')
# ('adeenrttv', 'advertent')
# ('aaddiilnot', 'additional')
# ('aceffhi', 'affiche')
# ('accdinoor', 'accordion')
# ('adiimnoss', 'admission')
# ('aabbcenors', 'absorbance')
# ('aefghorrttw', 'aftergrowth')
# ('acceoprt', 'acceptor')
# ('aadhiooprsu', 'adiaphorous')
# ('adeiinst', 'adenitis')
# ('ablotv', 'abvolt')
# ('aacgloory', 'acarology')
# ('abceegiinot', 'abiogenetic')
# ('acder', 'acred')
# ('acehlssuy', 'aeschylus')
# ('aabbcy', 'abbacy')
# ('aaaccilorstu', 'accusatorial')
# ('adentv', 'advent')
# ('aadffiitv', 'affidavit')
# ('abf', 'afb')
# ('abciiot', 'abiotic')
# ('aadrsstu', 'adrastus')
# ('aacfinr', 'african')
# ('aacdiirt', 'adriatic')
# ('aadelnsu', 'aalesund')
# ('aaceffirt', 'affricate')
# ('aadelnr', 'adrenal')
# ('abcdeiiort', 'aborticide')
# ('aachnostu', 'acanthous')
# ('aadhiimoprs', 'adiaphorism')
# ('abdeiilmss', 'admissible')
# ('abginttu', 'abutting')
# ('aaceffilnot', 'affectional')
# ('aacehimortz', 'achromatize')
# ('aabcdeit', 'abdicate')
# ('ablmoo', 'abloom')
# ('aaccdeilnt', 'accidental')
# ('adees', 'aedes')
# ('abdeo', 'abode, adobe')
# ('adiort', 'adroit')
# ('aabdlmru', 'adumbral')
# ('acceiiinprt', 'accipitrine')
# ('aaceglmory', 'acromegaly')
# ('adeelrrtu', 'adulterer')
# ('aaaru', 'aarau')
# ('aaabcehinrt', 'abranchiate')
# ('ademnnort', 'adornment')
# ('aadeltu', 'adulate')
# ('aacciinostu', 'acoustician')
# ('acdfiiy', 'acidify')
# ('aaeefrsttt', 'aftertaste')
# ('aegis', 'aegis')
# ('adffor', 'afford')
# ('acimmoss', 'acosmism')
# ('adz', 'adz')
# ('abeefnrrrtu', 'afterburner')
# ('aachmoorstu', 'achromatous')
# ('aaddeeil', 'adelaide')
# ('acort', 'actor')
# ('aabem', 'abeam')
# ('accesu', 'accuse')
# ('adehinos', 'adhesion')
# ('abinoort', 'abortion')
# ('aaacdeim', 'academia')
# ('abet', 'abet')
# ('acf', 'afc')
# ('abginnor', 'aborning')
# ('aeeffnrt', 'afferent')
# ('aacltu', 'actual')
# ('aabchor', 'abroach')
# ('acdi', 'acid')
# ('aaccr', 'accra')
# ('abmsy', 'abysm')
# ('aeemorrty', 'aerometry')
# ('abeeor', 'aerobe')
# ('aacdeem', 'academe')
# ('aaceffin', 'affiance')
# ('acdemoorr', 'acrodrome')
# ('abeeilmmoors', 'aeroembolism')
# ('acddit', 'addict')
# ('access', 'access')
# ('adeeemnorstuv', 'adventuresome')
# ('abde', 'abed')
# ('aablttu', 'abuttal')
# ('aaegimoopst', 'aegospotami')
# ('acehhilopt', 'achitophel')
# ('aaadinoptt', 'adaptation')
# ('abbdeors', 'absorbed')
# ('aaccdejny', 'adjacency')
# ('aabdeilmr', 'admirable')
# ('addeisv', 'advised')
# ('aeehoprty', 'aerophyte')
# ('aefir', 'afire')
# ('aaeegno', 'aegaeon')
# ('acchiimnooprt', 'actinomorphic')
# ('aacdefinrr', 'africander')
# ('aceehiimsstt', 'aestheticism')
# ('aaaaabbcdrr', 'abracadabra')
# ('aeeehoprrs', 'aerosphere')
# ('adeinorsuv', 'adenovirus')
# ('aaeeeghmoooprrrt', 'aerometeorograph')
# ('aabist', 'abatis')
# ('aceeffhinnprs', 'affenpinscher')
# ('aabenrrt', 'aberrant')
# ('abiioss', 'abiosis')
# ('acdeeiimrt', 'acidimeter')
# ('acdjntu', 'adjunct')
# ('aacccnnotuy', 'accountancy')
# ('abdnou', 'abound')
# ('aflou', 'afoul')
# ('aceenot', 'acetone')
# ('aabiimnnoot', 'abomination')
# ('aby', 'aby')
# ('abeeeimnsst', 'absenteeism')
# ('acdeelnost', 'adolescent')
# ('acceinort', 'accretion')
# ('adeeinn', 'adenine')
# ('abelosv', 'absolve')
# ('accdor', 'accord')
# ('aahrsu', 'aarhus')
# ('adeimnr', 'adermin')
# ('aabcdeery', 'abecedary')
# ('acemtu', 'acetum')
# ('acdhiilop', 'acidophil')
# ('aaeilot', 'aetolia')
# ('aadeimst', 'adamsite')
# ('aaabhmr', 'abraham')
# ('affiinty', 'affinity')
# ('aaccenptt', 'acceptant')
# ('aabenty', 'abeyant')
# ('acgint', 'acting')
# ('aadino', 'adonai')
# ('abellostuy', 'absolutely')
# ('adeeinnos', 'adenosine')
# ('acdddeit', 'addicted')
# ('abeefilr', 'afebrile')
# ('aacceilmtuuv', 'accumulative')
# ('accehiimnorstty', 'actinochemistry')
# ('aaabcdiit', 'adiabatic')
# ('accmostu', 'accustom')
# ('aceeemortt', 'acetometer')
# ('aaaccehnostu', 'acanthaceous')
# ('aadmn', 'adman')
# ('aabelz', 'ablaze')
# ('adelrtuy', 'adultery')
# ('abinoprtu', 'abruption')
# ('aabceert', 'acerbate')
# ('aaccilnorttuu', 'acculturation')
# ('acciimnnoty', 'actinomycin')
# ('aaaccilmnot', 'acclamation')
# ('abeisuv', 'abusive')
# ('aceffiiltv', 'afflictive')
# ('aceh', 'ache')
# ('aabck', 'aback')
# ('aacdeotv', 'advocate')
# ('aaabrsx', 'abraxas')
# ('aadr', 'adar')
# ('addiorty', 'additory')
# ('acdir', 'acrid')
# ('acdeiinr', 'acridine')
# ('aadeilnnr', 'adrenalin')
# ('aaffiimnort', 'affirmation')
# ('aaccelmtuu', 'accumulate')

# %% [markdown]
# Question: Why is the `grouped` RDD executed twice? How to force Spark to evaluate the `grouped` RDD only once?

# %% [markdown]
# You can also of course try out various other operations described during the course to familiarize yourself with them.
